# %% [markdown]
# **Download if necessary**

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/user/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### **Step 1: Import the libraries**

# %%
import nltk
import numpy as np
import random
import string

from bs4 import BeautifulSoup
import urllib.request
import re

# %% [markdown]
# ### Step 2: Grab articles from wikipedia

# %%
# Define URL and headers (pretend to be a real browser)
url = "https://en.wikipedia.org/wiki/Natural_language_processing"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

# Create a request object with headers
req = urllib.request.Request(url, headers=headers)

# Open and read the page
with urllib.request.urlopen(req) as response:
    raw_html = response.read()

# Parse the HTML using BeautifulSoup
article_html = BeautifulSoup(raw_html, "lxml")

# Extract all paragraph tags
article_paragraphs = article_html.find_all("p")

# Combine all text into one string
article_text = ""
for para in article_paragraphs:
    article_text += para.get_text()

# %%
article_text
# Out:
# '\nNatural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.\nNatural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\nThe premise of symbolic NLP is often illustrated using John Searle\'s Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\nUp until the 1980s, most natural language processing systems were based on complex sets of hand-written rules. Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing. This shift was influenced by increasing computational power (see Moore\'s law) and a decline in the dominance of Chomskyan linguistic theories... (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.[9]\nSymbolic approach, i.e., the hand-coding of a set of rules for manipulating symbols, coupled with a dictionary lookup, was historically the first approach used both by AI in general and by NLP in particular:[19][20] such as by writing grammars or devising heuristic rules for stemming.\nMachine learning approaches, which include both statistical and neural networks, on the other hand, have many advantages over the symbolic approach:\nRule-based systems are commonly used:\nIn the late 1980s and mid-1990s, the statistical approach ended a period of AI winter, which was caused by the inefficiencies of the rule-based approaches.[21][22]\nThe earliest decision trees, producing systems of hard if–then rules, were still very similar to the old rule-based approaches.\nOnly the introduction of hidden Markov models, applied to part-of-speech tagging, announced the end of the old rule-based approach.\nA major drawback of statistical methods is that they require elaborate feature engineering. Since 2015,[23] neural network–based methods have increasingly replaced traditional statistical approaches, using semantic networks[24] and word embeddings to capture semantic properties of words.\nIntermediate tasks (e.g., part-of-speech tagging and dependency parsing) are not needed anymore.\nNeural machine translation, based on then-newly invented sequence-to-sequence transformations, made obsolete the intermediate steps, such as word alignment, previously necessary for statistical machine translation.\nThe following is a list of some of the most commonly researched tasks in natural language processing. Some of these tasks have direct real-world applications, while others more commonly serve as subtasks that are used to aid in solving larger tasks.\nThough natural language processing tasks are closely intertwined, they can be subdivided into categories for convenience. A coarse division is given below.\nBased on long-standing trends in the field, it is possible to extrapolate future directions of NLP. As of 2020, three trends among the topics of the long-standing series of CoNLL Shared Tasks can be observed:[49]\nMost high ...

# %% [markdown]
# ### Step 4: N-Grams = 3

# %%
ngrams = {}
words = 3

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])

ngrams
# Out:
# Natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) is
# ) is the
# is the processing
# the processing of
# processing of natural
# of natural language
# natural language information
# language information by
# information by a
# by a computer
# a computer .
# computer . NLP
# . NLP is
# NLP is a
# is a subfield
# a subfield of
# subfield of computer
# of computer science
# computer science and
# science and is
# and is closely
# is closely associated
# closely associated with
# associated with artificial
# with artificial intelligence
# artificial intelligence .
# intelligence . NLP
# . NLP is
# NLP is also
# is also related
# also related to
# related to information
# to information retrieval
# information retrieval ,
# retrieval , knowledge
# , knowledge representation
# knowledge representation ,
# representation , computational
# , computational linguistics
# computational linguistics ,
# linguistics , and
# , and linguistics
# and linguistics more
# linguistics more broadly
# more broadly .
# broadly . [
# . [ 1
# [ 1 ]
# 1 ] Major
# ] Major processing
# Major processing tasks
# processing tasks in
# tasks in an
# in an NLP
# an NLP system
# NLP system include
# system include :
# include : speech
# : speech recognition
# speech recognition ,
# recognition , text
# , text classification
# text classification ,
# classification , natural
# , natural language
# natural language understanding
# language understanding ,
# understanding , and
# , and natural
# and natural language
# natural language generation
# language generation .
# generation . Natural
# . Natural language
# Natural language processing
# language processing has
# processing has its
# has its roots
# its roots in
# roots in the
# in the 1950s
# the 1950s .
# 1950s . [
# . [ 2
# [ 2 ]
# 2 ] Already
# ] Already in
# Already in 1950
# in 1950 ,
# 1950 , Alan
# , Alan Turing
# Alan Turing published
# Turing published an
# published an article
# an article titled
# article titled ``
# titled `` Computing
# `` Computing Machinery
# Computing Machinery and
# Machinery and Intelligence
# and Intelligence ''
# Intelligence '' which
# '' which proposed
# which proposed what
# proposed what is
# what is now
# is now called
# now called the
# called the Turing
# the Turing test
# Turing test as
# test as a
# as a criterion
# a criterion of
# criterion of intelligence
# of intelligence ,
# intelligence , though
# , though at
# though at the
# at the time
# the time that
# time that was
# that was not
# was not articulated
# not articulated as
# articulated as a
# as a problem
# a problem separate
# problem separate from
# separate from artificial
# from artificial intelligence
# artificial intelligence .
# intelligence . The
# . The proposed
# The proposed test
# proposed test includes
# test includes a
# includes a task
# a task that
# task that involves
# that involves the
# involves the automated
# the automated interpretation
# automated interpretation and
# interpretation and generation
# and generation of
# generation of natural
# of natural language
# natural language .
# language . The
# . The premise
# The premise of
# premise of symbolic
# of symbolic NLP
# symbolic NLP is
# NLP is often
# is often illustrated
# often illustrated using
# illustrated using John
# using John Searle
# John Searle 's
# Searle 's Chinese
# 's Chinese room
# Chinese room thought
# room thought experiment
# thought experiment :
# experiment : Given
# : Given a
# Given a collection
# a collection of
# collection of rules
# of rules (
# rules ( e.g.
# ( e.g. ,
# e.g. , a
# , a Chinese
# a Chinese phrasebook
# Chinese phrasebook ,
# phrasebook , with
# , with questions
# with questions and
# questions and matching
# and matching answers
# matching answers )
# answers ) ,
# ) , the
# , the computer
# the computer emulates
# computer emulates natural
# emulates natural language
# natural language understanding
# language understanding (
# understanding ( or
# ( or other
# or other NLP
# other NLP tasks
# NLP tasks )
# tasks ) by
# ) by applying
# by applying those
# applying those rules
# those rules to
# rules to the
# to the data
# the data it
# data it confronts
# it confronts .
# confronts . Up
# . Up until
# Up until the
# until the 1980s
# the 1980s ,
# 1980s , most
# , most natural
# most natural language
# natural language processing
# language processing systems
# processing systems were
# systems were based
# were based on
# based on complex
# on complex sets
# complex sets of
# sets of hand-written
# of hand-written rules
# hand-written rules .
# rules . Starting
# . Starting in
# Starting in the
# in the late
# the late 1980s
# late 1980s ,
# 1980s , however
# , however ,
# however , there
# , there was
# there was a
# was a revolution
# a revolution in
# revolution in natural
# in natural language
# natural language processing
# language processing with
# processing with the
# with the introduction
# the introduction of
# introduction of machine
# of machine learning
# machine learning algorithms
# learning algorithms for
# algorithms for language
# for language processing
# language processing .
# processing . This
# . This shift
# This shift was
# shift was influenced
# was influenced by
# influenced by increasing
# by increasing computational
# increasing computational power
# computational power (
# power ( see
# ( see Moore
# see Moore 's
# Moore 's law
# 's law )
# law ) and
# ) and a
# and a decline
# a decline in
# decline in the
# in the dominance
# the dominance of
# dominance of Chomskyan
# of Chomskyan linguistic
# Chomskyan linguistic theories
# linguistic theories ...
# theories ... (
# ... ( e.g
# ( e.g .
# e.g . transformational
# . transformational grammar
# transformational grammar )
# grammar ) ,
# ) , whose
# , whose theoretical
# whose theoretical underpinnings
# theoretical underpinnings discouraged
# underpinnings discouraged the
# discouraged the sort
# the sort of
# sort of corpus
# of corpus linguistics
# corpus linguistics that
# linguistics that underlies
# that underlies the
# underlies the machine-learning
# the machine-learning approach
# machine-learning approach to
# approach to language
# to language processing
# language processing .
# processing . [
# . [ 9
# [ 9 ]
# 9 ] Symbolic
# ] Symbolic approach
# Symbolic approach ,
# approach , i.e.
# , i.e. ,
# i.e. , the
# , the hand-coding
# the hand-coding of
# hand-coding of a
# of a set
# a set of
# set of rules
# of rules for
# rules for manipulating
# for manipulating symbols
# manipulating symbols ,
# symbols , coupled
# , coupled with
# coupled with a
# with a dictionary
# a dictionary lookup
# dictionary lookup ,
# lookup , was
# , was historically
# was historically the
# historically the first
# the first approach
# first approach used
# approach used both
# used both by
# both by AI
# by AI in
# AI in general
# in general and
# general and by
# and by NLP
# by NLP in
# NLP in particular
# in particular :
# particular : [
# : [ 19
# [ 19 ]
# 19 ] [
# ] [ 20
# [ 20 ]
# 20 ] such
# ] such as
# such as by
# as by writing
# by writing grammars
# writing grammars or
# grammars or devising
# or devising heuristic
# devising heuristic rules
# heuristic rules for
# rules for stemming
# for stemming .
# stemming . Machine
# . Machine learning
# Machine learning approaches
# learning approaches ,
# approaches , which
# , which include
# which include both
# include both statistical
# both statistical and
# statistical and neural
# and neural networks
# neural networks ,
# networks , on
# , on the
# on the other
# the other hand
# other hand ,
# hand , have
# , have many
# have many advantages
# many advantages over
# advantages over the
# over the symbolic
# the symbolic approach
# symbolic approach :
# approach : Rule-based
# : Rule-based systems
# Rule-based systems are
# systems are commonly
# are commonly used
# commonly used :
# used : In
# : In the
# In the late
# the late 1980s
# late 1980s and
# 1980s and mid-1990s
# and mid-1990s ,
# mid-1990s , the
# , the statistical
# the statistical approach
# statistical approach ended
# approach ended a
# ended a period
# a period of
# period of AI
# of AI winter
# AI winter ,
# winter , which
# , which was
# which was caused
# was caused by
# caused by the
# by the inefficiencies
# the inefficiencies of
# inefficiencies of the
# of the rule-based
# the rule-based approaches
# rule-based approaches .
# approaches . [
# . [ 21
# [ 21 ]
# 21 ] [
# ] [ 22
# [ 22 ]
# 22 ] The
# ] The earliest
# The earliest decision
# earliest decision trees
# decision trees ,
# trees , producing
# , producing systems
# producing systems of
# systems of hard
# of hard if–then
# hard if–then rules
# if–then rules ,
# rules , were
# , were still
# were still very
# still very similar
# very similar to
# similar to the
# to the old
# the old rule-based
# old rule-based approaches
# rule-based approaches .
# approaches . Only
# . Only the
# Only the introduction
# the introduction of
# introduction of hidden
# of hidden Markov
# hidden Markov models
# Markov models ,
# models , applied
# , applied to
# applied to part-of-speech
# to part-of-speech tagging
# part-of-speech tagging ,
# tagging , announced
# , announced the
# announced the end
# the end of
# end of the
# of the old
# the old rule-based
# old rule-based approach
# rule-based approach .
# approach . A
# . A major
# A major drawback
# major drawback of
# drawback of statistical
# of statistical methods
# statistical methods is
# methods is that
# is that they
# that they require
# they require elaborate
# require elaborate feature
# elaborate feature engineering
# feature engineering .
# engineering . Since
# . Since 2015
# Since 2015 ,
# 2015 , [
# , [ 23
# [ 23 ]
# 23 ] neural
# ] neural network–based
# neural network–based methods
# network–based methods have
# methods have increasingly
# have increasingly replaced
# increasingly replaced traditional
# replaced traditional statistical
# traditional statistical approaches
# statistical approaches ,
# approaches , using
# , using semantic
# using semantic networks
# semantic networks [
# networks [ 24
# [ 24 ]
# 24 ] and
# ] and word
# and word embeddings
# word embeddings to
# embeddings to capture
# to capture semantic
# capture semantic properties
# semantic properties of
# properties of words
# of words .
# words . Intermediate
# . Intermediate tasks
# Intermediate tasks (
# tasks ( e.g.
# ( e.g. ,
# e.g. , part-of-speech
# , part-of-speech tagging
# part-of-speech tagging and
# tagging and dependency
# and dependency parsing
# dependency parsing )
# parsing ) are
# ) are not
# are not needed
# not needed anymore
# needed anymore .
# anymore . Neural
# . Neural machine
# Neural machine translation
# machine translation ,
# translation , based
# , based on
# based on then-newly
# on then-newly invented
# then-newly invented sequence-to-sequence
# invented sequence-to-sequence transformations
# sequence-to-sequence transformations ,
# transformations , made
# , made obsolete
# made obsolete the
# obsolete the intermediate
# the intermediate steps
# intermediate steps ,
# steps , such
# , such as
# such as word
# as word alignment
# word alignment ,
# alignment , previously
# , previously necessary
# previously necessary for
# necessary for statistical
# for statistical machine
# statistical machine translation
# machine translation .
# translation . The
# . The following
# The following is
# following is a
# is a list
# a list of
# list of some
# of some of
# some of the
# of the most
# the most commonly
# most commonly researched
# commonly researched tasks
# researched tasks in
# tasks in natural
# in natural language
# natural language processing
# language processing .
# processing . Some
# . Some of
# Some of these
# of these tasks
# these tasks have
# tasks have direct
# have direct real-world
# direct real-world applications
# real-world applications ,
# applications , while
# , while others
# while others more
# others more commonly
# more commonly serve
# commonly serve as
# serve as subtasks
# as subtasks that
# subtasks that are
# that are used
# are used to
# used to aid
# to aid in
# aid in solving
# in solving larger
# solving larger tasks
# larger tasks .
# tasks . Though
# . Though natural
# Though natural language
# natural language processing
# language processing tasks
# processing tasks are
# tasks are closely
# are closely intertwined
# closely intertwined ,
# intertwined , they
# , they can
# they can be
# can be subdivided
# be subdivided into
# subdivided into categories
# into categories for
# categories for convenience
# for convenience .
# convenience . A
# . A coarse
# A coarse division
# coarse division is
# division is given
# is given below
# given below .
# below . Based
# . Based on
# Based on long-standing
# on long-standing trends
# long-standing trends in
# trends in the
# in the field
# the field ,
# field , it
# , it is
# it is possible
# is possible to
# possible to extrapolate
# to extrapolate future
# extrapolate future directions
# future directions of
# directions of NLP
# of NLP .
# NLP . As
# . As of
# As of 2020
# of 2020 ,
# 2020 , three
# , three trends
# three trends among
# trends among the
# among the topics
# the topics of
# topics of the
# of the long-standing
# the long-standing series
# long-standing series of
# series of CoNLL
# of CoNLL Shared
# CoNLL Shared Tasks
# Shared Tasks can
# Tasks can be
# can be observed
# be observed :
# observed : [
# : [ 49
# [ 49 ]
# 49 ] Most
# ] Most higher-level
# Most higher-level NLP
# higher-level NLP applications
# NLP applications involve
# applications involve aspects
# involve aspects that
# aspects that emulate
# that emulate intelligent
# emulate intelligent behavior
# intelligent behavior and
# behavior and apparent
# and apparent comprehension
# apparent comprehension of
# comprehension of natural
# of natural language
# natural language .
# language . More
# . More broadly
# More broadly speaking
# broadly speaking ,
# speaking , the
# , the technical
# the technical operationalization
# technical operationalization of
# operationalization of increasingly
# of increasingly advanced
# increasingly advanced aspects
# advanced aspects of
# aspects of cognitive
# of cognitive behavior
# cognitive behavior represents
# behavior represents one
# represents one of
# one of the
# of the developmental
# the developmental trajectories
# developmental trajectories of
# trajectories of NLP
# of NLP (
# NLP ( see
# ( see trends
# see trends among
# trends among CoNLL
# among CoNLL shared
# CoNLL shared tasks
# shared tasks above
# tasks above )
# above ) .
# ) . Cognition
# . Cognition refers
# Cognition refers to
# refers to ``
# to `` the
# `` the mental
# the mental action
# mental action or
# action or process
# or process of
# process of acquiring
# of acquiring knowledge
# acquiring knowledge and
# knowledge and understanding
# and understanding through
# understanding through thought
# through thought ,
# thought , experience
# , experience ,
# experience , and
# , and the
# and the senses
# the senses .
# senses . ``
# . `` [
# `` [ 50
# [ 50 ]
# 50 ] Cognitive
# ] Cognitive science
# Cognitive science is
# science is the
# is the interdisciplinary
# the interdisciplinary ,
# interdisciplinary , scientific
# , scientific study
# scientific study of
# study of the
# of the mind
# the mind and
# mind and its
# and its processes
# its processes .
# processes . [
# . [ 51
# [ 51 ]
# 51 ] Cognitive
# ] Cognitive linguistics
# Cognitive linguistics is
# linguistics is an
# is an interdisciplinary
# an interdisciplinary branch
# interdisciplinary branch of
# branch of linguistics
# of linguistics ,
# linguistics , combining
# , combining knowledge
# combining knowledge and
# knowledge and research
# and research from
# research from both
# from both psychology
# both psychology and
# psychology and linguistics
# and linguistics .
# linguistics . [
# . [ 52
# [ 52 ]
# 52 ] Especially
# ] Especially during
# Especially during the
# during the age
# the age of
# age of symbolic
# of symbolic NLP
# symbolic NLP ,
# NLP , the
# , the area
# the area of
# area of computational
# of computational linguistics
# computational linguistics maintained
# linguistics maintained strong
# maintained strong ties
# strong ties with
# ties with cognitive
# with cognitive studies
# cognitive studies .
# studies . As
# . As an
# As an example
# an example ,
# example , George
# , George Lakoff
# George Lakoff offers
# Lakoff offers a
# offers a methodology
# a methodology to
# methodology to build
# to build natural
# build natural language
# natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) algorithms
# ) algorithms through
# algorithms through the
# through the perspective
# the perspective of
# perspective of cognitive
# of cognitive science
# cognitive science ,
# science , along
# , along with
# along with the
# with the findings
# the findings of
# findings of cognitive
# of cognitive linguistics
# cognitive linguistics ,
# linguistics , [
# , [ 53
# [ 53 ]
# 53 ] with
# ] with two
# with two defining
# two defining aspects
# defining aspects :
# aspects : Ties
# : Ties with
# Ties with cognitive
# with cognitive linguistics
# cognitive linguistics are
# linguistics are part
# are part of
# part of the
# of the historical
# the historical heritage
# historical heritage of
# heritage of NLP
# of NLP ,
# NLP , but
# , but they
# but they have
# they have been
# have been less
# been less frequently
# less frequently addressed
# frequently addressed since
# addressed since the
# since the statistical
# the statistical turn
# statistical turn during
# turn during the
# during the 1990s
# the 1990s .
# 1990s . Nevertheless
# . Nevertheless ,
# Nevertheless , approaches
# , approaches to
# approaches to develop
# to develop cognitive
# develop cognitive models
# cognitive models towards
# models towards technically
# towards technically operationalizable
# technically operationalizable frameworks
# operationalizable frameworks have
# frameworks have been
# have been pursued
# been pursued in
# pursued in the
# in the context
# the context of
# context of various
# of various frameworks
# various frameworks ,
# frameworks , e.g.
# , e.g. ,
# e.g. , of
# , of cognitive
# of cognitive grammar
# cognitive grammar ,
# grammar , [
# , [ 56
# [ 56 ]
# 56 ] functional
# ] functional grammar
# functional grammar ,
# grammar , [
# , [ 57
# [ 57 ]
# 57 ] construction
# ] construction grammar
# construction grammar ,
# grammar , [
# , [ 58
# [ 58 ]
# 58 ] computational
# ] computational psycholinguistics
# computational psycholinguistics and
# psycholinguistics and cognitive
# and cognitive neuroscience
# cognitive neuroscience (
# neuroscience ( e.g.
# ( e.g. ,
# e.g. , ACT-R
# , ACT-R )
# ACT-R ) ,
# ) , however
# , however ,
# however , with
# , with limited
# with limited uptake
# limited uptake in
# uptake in mainstream
# in mainstream NLP
# mainstream NLP (
# NLP ( as
# ( as measured
# as measured by
# measured by presence
# by presence on
# presence on major
# on major conferences
# major conferences [
# conferences [ 59
# [ 59 ]
# 59 ] of
# ] of the
# of the ACL
# the ACL )
# ACL ) .
# ) . More
# . More recently
# More recently ,
# recently , ideas
# , ideas of
# ideas of cognitive
# of cognitive NLP
# cognitive NLP have
# NLP have been
# have been revived
# been revived as
# revived as an
# as an approach
# an approach to
# approach to achieve
# to achieve explainability
# achieve explainability ,
# explainability , e.g.
# , e.g. ,
# e.g. , under
# , under the
# under the notion
# the notion of
# notion of ``
# of `` cognitive
# `` cognitive AI
# cognitive AI ''
# AI '' .
# '' . [
# . [ 60
# [ 60 ]
# 60 ] Likewise
# ] Likewise ,
# Likewise , ideas
# , ideas of
# ideas of cognitive
# of cognitive NLP
# cognitive NLP are
# NLP are inherent
# are inherent to
# inherent to neural
# to neural models
# neural models multimodal
# models multimodal NLP
# multimodal NLP (
# NLP ( although
# ( although rarely
# although rarely made
# rarely made explicit
# made explicit )
# explicit ) [
# ) [ 61
# [ 61 ]
# 61 ] and
# ] and developments
# and developments in
# developments in artificial
# in artificial intelligence
# artificial intelligence ,
# intelligence , specifically
# , specifically tools
# specifically tools and
# tools and technologies
# and technologies using
# technologies using large
# using large language
# large language model
# language model approaches
# model approaches [
# approaches [ 62
# [ 62 ]
# 62 ] and
# ] and new
# and new directions
# new directions in
# directions in artificial
# in artificial general
# artificial general intelligence
# general intelligence based
# intelligence based on
# based on the
# on the free
# the free energy
# free energy principle
# energy principle [
# principle [ 63
# [ 63 ]
# 63 ] by
# ] by British
# by British neuroscientist
# British neuroscientist and
# neuroscientist and theoretician
# and theoretician at
# theoretician at University
# at University College
# University College London
# College London Karl
# London Karl J.
# Karl J. Friston
# {'Natural language processing': ['(', 'has'],
#  'language processing (': ['NLP', 'NLP'],
#  'processing ( NLP': [')', ')'],
#  '( NLP )': ['is', 'algorithms'],
#  'NLP ) is': ['the'],
#  ') is the': ['processing'],
#  'is the processing': ['of'],
#  'the processing of': ['natural'],
#  'processing of natural': ['language'],
#  'of natural language': ['information', '.', '.'],
#  'natural language information': ['by'],
#  'language information by': ['a'],
#  'information by a': ['computer'],
#  'by a computer': ['.'],
#  'a computer .': ['NLP'],
#  'computer . NLP': ['is'],
#  '. NLP is': ['a', 'also'],
#  'NLP is a': ['subfield'],
#  'is a subfield': ['of'],
#  'a subfield of': ['computer'],
#  'subfield of computer': ['science'],
#  'of computer science': ['and'],
#  'computer science and': ['is'],
#  'science and is': ['closely'],
#  'and is closely': ['associated'],
#  'is closely associated': ['with'],
#  'closely associated with': ['artificial'],
#  'associated with artificial': ['intelligence'],
#  'with artificial intelligence': ['.'],
#  'artificial intelligence .': ['NLP', 'The'],
#  'intelligence . NLP': ['is'],
#  'NLP is also': ['related'],
#  'is also related': ['to'],
#  'also related to': ['information'],
#  'related to information': ['retrieval'],
#  'to information retrieval': [','],
#  'information retrieval ,': ['knowledge'],
#  'retrieval , knowledge': ['representation'],
#  ', knowledge representation': [','],
#  'knowledge representation ,': ['computational'],
#  'representation , computational': ['linguistics'],
#  ', computational linguistics': [','],
#  'computational linguistics ,': ['and'],
#  'linguistics , and': ['linguistics'],
#  ', and linguistics': ['more'],
#  'and linguistics more': ['broadly'],
#  'linguistics more broadly': ['.'],
#  'more broadly .': ['['],
#  'broadly . [': ['1'],
#  '. [ 1': [']'],
#  '[ 1 ]': ['Major'],
#  '1 ] Major': ['processing'],
#  '] Major processing': ['tasks'],
#  'Major processing tasks': ['in'],
#  'processing tasks in': ['an'],
#  'tasks in an': ['NLP'],
#  'in an NLP': ['system'],
#  'an NLP system': ['include'],
#  'NLP system include': [':'],
#  'system include :': ['speech'],
#  'include : speech': ['recognition'],
#  ': speech recognition': [','],
#  'speech recognition ,': ['text'],
#  'recognition , text': ['classification'],
#  ', text classification': [','],
#  'text classification ,': ['natural'],
#  'classification , natural': ['language'],
#  ', natural language': ['understanding'],
#  'natural language understanding': [',', '('],
#  'language understanding ,': ['and'],
#  'understanding , and': ['natural'],
#  ', and natural': ['language'],
#  'and natural language': ['generation'],
#  'natural language generation': ['.'],
#  'language generation .': ['Natural'],
#  'generation . Natural': ['language'],
#  '. Natural language': ['processing'],
#  'language processing has': ['its'],
#  'processing has its': ['roots'],
#  'has its roots': ['in'],
#  'its roots in': ['the'],
#  'roots in the': ['1950s'],
#  'in the 1950s': ['.'],
#  'the 1950s .': ['['],
#  '1950s . [': ['2'],
#  '. [ 2': [']'],
#  '[ 2 ]': ['Already'],
#  '2 ] Already': ['in'],
#  '] Already in': ['1950'],
#  'Already in 1950': [','],
#  'in 1950 ,': ['Alan'],
#  '1950 , Alan': ['Turing'],
#  ', Alan Turing': ['published'],
#  'Alan Turing published': ['an'],
#  'Turing published an': ['article'],
#  'published an article': ['titled'],
#  'an article titled': ['``'],
#  'article titled ``': ['Computing'],
#  'titled `` Computing': ['Machinery'],
#  '`` Computing Machinery': ['and'],
#  'Computing Machinery and': ['Intelligence'],
#  'Machinery and Intelligence': ["''"],
#  "and Intelligence ''": ['which'],
#  "Intelligence '' which": ['proposed'],
#  "'' which proposed": ['what'],
#  'which proposed what': ['is'],
#  'proposed what is': ['now'],
#  'what is now': ['called'],
#  'is now called': ['the'],
#  'now called the': ['Turing'],
#  'called the Turing': ['test'],
#  'the Turing test': ['as'],
#  'Turing test as': ['a'],
#  'test as a': ['criterion'],
#  'as a criterion': ['of'],
#  'a criterion of': ['intelligence'],
#  'criterion of intelligence': [','],
#  'of intelligence ,': ['though'],
#  'intelligence , though': ['at'],
#  ', though at': ['the'],
#  'though at the': ['time'],
#  'at the time': ['that'],
#  'the time that': ['was'],
#  'time that was': ['not'],
#  'that was not': ['articulated'],
#  'was not articulated': ['as'],
#  'not articulated as': ['a'],
#  'articulated as a': ['problem'],
#  'as a problem': ['separate'],
#  'a problem separate': ['from'],
#  'problem separate from': ['artificial'],
#  'separate from artificial': ['intelligence'],
#  'from artificial intelligence': ['.'],
#  'intelligence . The': ['proposed'],
#  '. The proposed': ['test'],
#  'The proposed test': ['includes'],
#  'proposed test includes': ['a'],
#  'test includes a': ['task'],
#  'includes a task': ['that'],
#  'a task that': ['involves'],
#  'task that involves': ['the'],
#  'that involves the': ['automated'],
#  'involves the automated': ['interpretation'],
#  'the automated interpretation': ['and'],
#  'automated interpretation and': ['generation'],
#  'interpretation and generation': ['of'],
#  'and generation of': ['natural'],
#  'generation of natural': ['language'],
#  'natural language .': ['The', 'More'],
#  'language . The': ['premise'],
#  '. The premise': ['of'],
#  'The premise of': ['symbolic'],
#  'premise of symbolic': ['NLP'],
#  'of symbolic NLP': ['is', ','],
#  'symbolic NLP is': ['often'],
#  'NLP is often': ['illustrated'],
#  'is often illustrated': ['using'],
#  'often illustrated using': ['John'],
#  'illustrated using John': ['Searle'],
#  'using John Searle': ["'s"],
#  "John Searle 's": ['Chinese'],
#  "Searle 's Chinese": ['room'],
#  "'s Chinese room": ['thought'],
#  'Chinese room thought': ['experiment'],
#  'room thought experiment': [':'],
#  'thought experiment :': ['Given'],
#  'experiment : Given': ['a'],
#  ': Given a': ['collection'],
#  'Given a collection': ['of'],
#  'a collection of': ['rules'],
#  'collection of rules': ['('],
#  'of rules (': ['e.g.'],
#  'rules ( e.g.': [','],
#  '( e.g. ,': ['a', 'part-of-speech', 'ACT-R'],
#  'e.g. , a': ['Chinese'],
#  ', a Chinese': ['phrasebook'],
#  'a Chinese phrasebook': [','],
#  'Chinese phrasebook ,': ['with'],
#  'phrasebook , with': ['questions'],
#  ', with questions': ['and'],
#  'with questions and': ['matching'],
#  'questions and matching': ['answers'],
#  'and matching answers': [')'],
#  'matching answers )': [','],
#  'answers ) ,': ['the'],
#  ') , the': ['computer'],
#  ', the computer': ['emulates'],
#  'the computer emulates': ['natural'],
#  'computer emulates natural': ['language'],
#  'emulates natural language': ['understanding'],
#  'language understanding (': ['or'],
#  'understanding ( or': ['other'],
#  '( or other': ['NLP'],
#  'or other NLP': ['tasks'],
#  'other NLP tasks': [')'],
#  'NLP tasks )': ['by'],
#  'tasks ) by': ['applying'],
#  ') by applying': ['those'],
#  'by applying those': ['rules'],
#  'applying those rules': ['to'],
#  'those rules to': ['the'],
#  'rules to the': ['data'],
#  'to the data': ['it'],
#  'the data it': ['confronts'],
#  'data it confronts': ['.'],
#  'it confronts .': ['Up'],
#  'confronts . Up': ['until'],
#  '. Up until': ['the'],
#  'Up until the': ['1980s'],
#  'until the 1980s': [','],
#  'the 1980s ,': ['most'],
#  '1980s , most': ['natural'],
#  ', most natural': ['language'],
#  'most natural language': ['processing'],
#  'natural language processing': ['systems', 'with', '.', 'tasks', '('],
#  'language processing systems': ['were'],
#  'processing systems were': ['based'],
#  'systems were based': ['on'],
#  'were based on': ['complex'],
#  'based on complex': ['sets'],
#  'on complex sets': ['of'],
#  'complex sets of': ['hand-written'],
#  'sets of hand-written': ['rules'],
#  'of hand-written rules': ['.'],
#  'hand-written rules .': ['Starting'],
#  'rules . Starting': ['in'],
#  '. Starting in': ['the'],
#  'Starting in the': ['late'],
#  'in the late': ['1980s'],
#  'the late 1980s': [',', 'and'],
#  'late 1980s ,': ['however'],
#  '1980s , however': [','],
#  ', however ,': ['there', 'with'],
#  'however , there': ['was'],
#  ', there was': ['a'],
#  'there was a': ['revolution'],
#  'was a revolution': ['in'],
#  'a revolution in': ['natural'],
#  'revolution in natural': ['language'],
#  'in natural language': ['processing', 'processing'],
#  'language processing with': ['the'],
#  'processing with the': ['introduction'],
#  'with the introduction': ['of'],
#  'the introduction of': ['machine', 'hidden'],
#  'introduction of machine': ['learning'],
#  'of machine learning': ['algorithms'],
#  'machine learning algorithms': ['for'],
#  'learning algorithms for': ['language'],
#  'algorithms for language': ['processing'],
#  'for language processing': ['.'],
#  'language processing .': ['This', '[', 'Some'],
#  'processing . This': ['shift'],
#  '. This shift': ['was'],
#  'This shift was': ['influenced'],
#  'shift was influenced': ['by'],
#  'was influenced by': ['increasing'],
#  'influenced by increasing': ['computational'],
#  'by increasing computational': ['power'],
#  'increasing computational power': ['('],
#  'computational power (': ['see'],
#  'power ( see': ['Moore'],
#  '( see Moore': ["'s"],
#  "see Moore 's": ['law'],
#  "Moore 's law": [')'],
#  "'s law )": ['and'],
#  'law ) and': ['a'],
#  ') and a': ['decline'],
#  'and a decline': ['in'],
#  'a decline in': ['the'],
#  'decline in the': ['dominance'],
#  'in the dominance': ['of'],
#  'the dominance of': ['Chomskyan'],
#  'dominance of Chomskyan': ['linguistic'],
#  'of Chomskyan linguistic': ['theories'],
#  'Chomskyan linguistic theories': ['...'],
#  'linguistic theories ...': ['('],
#  'theories ... (': ['e.g'],
#  '... ( e.g': ['.'],
#  '( e.g .': ['transformational'],
#  'e.g . transformational': ['grammar'],
#  '. transformational grammar': [')'],
#  'transformational grammar )': [','],
#  'grammar ) ,': ['whose'],
#  ') , whose': ['theoretical'],
#  ', whose theoretical': ['underpinnings'],
#  'whose theoretical underpinnings': ['discouraged'],
#  'theoretical underpinnings discouraged': ['the'],
#  'underpinnings discouraged the': ['sort'],
#  'discouraged the sort': ['of'],
#  'the sort of': ['corpus'],
#  'sort of corpus': ['linguistics'],
#  'of corpus linguistics': ['that'],
#  'corpus linguistics that': ['underlies'],
#  'linguistics that underlies': ['the'],
#  'that underlies the': ['machine-learning'],
#  'underlies the machine-learning': ['approach'],
#  'the machine-learning approach': ['to'],
#  'machine-learning approach to': ['language'],
#  'approach to language': ['processing'],
#  'to language processing': ['.'],
#  'processing . [': ['9'],
#  '. [ 9': [']'],
#  '[ 9 ]': ['Symbolic'],
#  '9 ] Symbolic': ['approach'],
#  '] Symbolic approach': [','],
#  'Symbolic approach ,': ['i.e.'],
#  'approach , i.e.': [','],
#  ', i.e. ,': ['the'],
#  'i.e. , the': ['hand-coding'],
#  ', the hand-coding': ['of'],
#  'the hand-coding of': ['a'],
#  'hand-coding of a': ['set'],
#  'of a set': ['of'],
#  'a set of': ['rules'],
#  'set of rules': ['for'],
#  'of rules for': ['manipulating'],
#  'rules for manipulating': ['symbols'],
#  'for manipulating symbols': [','],
#  'manipulating symbols ,': ['coupled'],
#  'symbols , coupled': ['with'],
#  ', coupled with': ['a'],
#  'coupled with a': ['dictionary'],
#  'with a dictionary': ['lookup'],
#  'a dictionary lookup': [','],
#  'dictionary lookup ,': ['was'],
#  'lookup , was': ['historically'],
#  ', was historically': ['the'],
#  'was historically the': ['first'],
#  'historically the first': ['approach'],
#  'the first approach': ['used'],
#  'first approach used': ['both'],
#  'approach used both': ['by'],
#  'used both by': ['AI'],
#  'both by AI': ['in'],
#  'by AI in': ['general'],
#  'AI in general': ['and'],
#  'in general and': ['by'],
#  'general and by': ['NLP'],
#  'and by NLP': ['in'],
#  'by NLP in': ['particular'],
#  'NLP in particular': [':'],
#  'in particular :': ['['],
#  'particular : [': ['19'],
#  ': [ 19': [']'],
#  '[ 19 ]': ['['],
#  '19 ] [': ['20'],
#  '] [ 20': [']'],
#  '[ 20 ]': ['such'],
#  '20 ] such': ['as'],
#  '] such as': ['by'],
#  'such as by': ['writing'],
#  'as by writing': ['grammars'],
#  'by writing grammars': ['or'],
#  'writing grammars or': ['devising'],
#  'grammars or devising': ['heuristic'],
#  'or devising heuristic': ['rules'],
#  'devising heuristic rules': ['for'],
#  'heuristic rules for': ['stemming'],
#  'rules for stemming': ['.'],
#  'for stemming .': ['Machine'],
#  'stemming . Machine': ['learning'],
#  '. Machine learning': ['approaches'],
#  'Machine learning approaches': [','],
#  'learning approaches ,': ['which'],
#  'approaches , which': ['include'],
#  ', which include': ['both'],
#  'which include both': ['statistical'],
#  'include both statistical': ['and'],
#  'both statistical and': ['neural'],
#  'statistical and neural': ['networks'],
#  'and neural networks': [','],
#  'neural networks ,': ['on'],
#  'networks , on': ['the'],
#  ', on the': ['other'],
#  'on the other': ['hand'],
#  'the other hand': [','],
#  'other hand ,': ['have'],
#  'hand , have': ['many'],
#  ', have many': ['advantages'],
#  'have many advantages': ['over'],
#  'many advantages over': ['the'],
#  'advantages over the': ['symbolic'],
#  'over the symbolic': ['approach'],
#  'the symbolic approach': [':'],
#  'symbolic approach :': ['Rule-based'],
#  'approach : Rule-based': ['systems'],
#  ': Rule-based systems': ['are'],
#  'Rule-based systems are': ['commonly'],
#  'systems are commonly': ['used'],
#  'are commonly used': [':'],
#  'commonly used :': ['In'],
#  'used : In': ['the'],
#  ': In the': ['late'],
#  'In the late': ['1980s'],
#  'late 1980s and': ['mid-1990s'],
#  '1980s and mid-1990s': [','],
#  'and mid-1990s ,': ['the'],
#  'mid-1990s , the': ['statistical'],
#  ', the statistical': ['approach'],
#  'the statistical approach': ['ended'],
#  'statistical approach ended': ['a'],
#  'approach ended a': ['period'],
#  'ended a period': ['of'],
#  'a period of': ['AI'],
#  'period of AI': ['winter'],
#  'of AI winter': [','],
#  'AI winter ,': ['which'],
#  'winter , which': ['was'],
#  ', which was': ['caused'],
#  'which was caused': ['by'],
#  'was caused by': ['the'],
#  'caused by the': ['inefficiencies'],
#  'by the inefficiencies': ['of'],
#  'the inefficiencies of': ['the'],
#  'inefficiencies of the': ['rule-based'],
#  'of the rule-based': ['approaches'],
#  'the rule-based approaches': ['.'],
#  'rule-based approaches .': ['[', 'Only'],
#  'approaches . [': ['21'],
#  '. [ 21': [']'],
#  '[ 21 ]': ['['],
#  '21 ] [': ['22'],
#  '] [ 22': [']'],
#  '[ 22 ]': ['The'],
#  '22 ] The': ['earliest'],
#  '] The earliest': ['decision'],
#  'The earliest decision': ['trees'],
#  'earliest decision trees': [','],
#  'decision trees ,': ['producing'],
#  'trees , producing': ['systems'],
#  ', producing systems': ['of'],
#  'producing systems of': ['hard'],
#  'systems of hard': ['if–then'],
#  'of hard if–then': ['rules'],
#  'hard if–then rules': [','],
#  'if–then rules ,': ['were'],
#  'rules , were': ['still'],
#  ', were still': ['very'],
#  'were still very': ['similar'],
#  'still very similar': ['to'],
#  'very similar to': ['the'],
#  'similar to the': ['old'],
#  'to the old': ['rule-based'],
#  'the old rule-based': ['approaches', 'approach'],
#  'old rule-based approaches': ['.'],
#  'approaches . Only': ['the'],
#  '. Only the': ['introduction'],
#  'Only the introduction': ['of'],
#  'introduction of hidden': ['Markov'],
#  'of hidden Markov': ['models'],
#  'hidden Markov models': [','],
#  'Markov models ,': ['applied'],
#  'models , applied': ['to'],
#  ', applied to': ['part-of-speech'],
#  'applied to part-of-speech': ['tagging'],
#  'to part-of-speech tagging': [','],
#  'part-of-speech tagging ,': ['announced'],
#  'tagging , announced': ['the'],
#  ', announced the': ['end'],
#  'announced the end': ['of'],
#  'the end of': ['the'],
#  'end of the': ['old'],
#  'of the old': ['rule-based'],
#  'old rule-based approach': ['.'],
#  'rule-based approach .': ['A'],
#  'approach . A': ['major'],
#  '. A major': ['drawback'],
#  'A major drawback': ['of'],
#  'major drawback of': ['statistical'],
#  'drawback of statistical': ['methods'],
#  'of statistical methods': ['is'],
#  'statistical methods is': ['that'],
#  'methods is that': ['they'],
#  'is that they': ['require'],
#  'that they require': ['elaborate'],
#  'they require elaborate': ['feature'],
#  'require elaborate feature': ['engineering'],
#  'elaborate feature engineering': ['.'],
#  'feature engineering .': ['Since'],
#  'engineering . Since': ['2015'],
#  '. Since 2015': [','],
#  'Since 2015 ,': ['['],
#  '2015 , [': ['23'],
#  ', [ 23': [']'],
#  '[ 23 ]': ['neural'],
#  '23 ] neural': ['network–based'],
#  '] neural network–based': ['methods'],
#  'neural network–based methods': ['have'],
#  'network–based methods have': ['increasingly'],
#  'methods have increasingly': ['replaced'],
#  'have increasingly replaced': ['traditional'],
#  'increasingly replaced traditional': ['statistical'],
#  'replaced traditional statistical': ['approaches'],
#  'traditional statistical approaches': [','],
#  'statistical approaches ,': ['using'],
#  'approaches , using': ['semantic'],
#  ', using semantic': ['networks'],
#  'using semantic networks': ['['],
#  'semantic networks [': ['24'],
#  'networks [ 24': [']'],
#  '[ 24 ]': ['and'],
#  '24 ] and': ['word'],
#  '] and word': ['embeddings'],
#  'and word embeddings': ['to'],
#  'word embeddings to': ['capture'],
#  'embeddings to capture': ['semantic'],
#  'to capture semantic': ['properties'],
#  'capture semantic properties': ['of'],
#  'semantic properties of': ['words'],
#  'properties of words': ['.'],
#  'of words .': ['Intermediate'],
#  'words . Intermediate': ['tasks'],
#  '. Intermediate tasks': ['('],
#  'Intermediate tasks (': ['e.g.'],
#  'tasks ( e.g.': [','],
#  'e.g. , part-of-speech': ['tagging'],
#  ', part-of-speech tagging': ['and'],
#  'part-of-speech tagging and': ['dependency'],
#  'tagging and dependency': ['parsing'],
#  'and dependency parsing': [')'],
#  'dependency parsing )': ['are'],
#  'parsing ) are': ['not'],
#  ') are not': ['needed'],
#  'are not needed': ['anymore'],
#  'not needed anymore': ['.'],
#  'needed anymore .': ['Neural'],
#  'anymore . Neural': ['machine'],
#  '. Neural machine': ['translation'],
#  'Neural machine translation': [','],
#  'machine translation ,': ['based'],
#  'translation , based': ['on'],
#  ', based on': ['then-newly'],
#  'based on then-newly': ['invented'],
#  'on then-newly invented': ['sequence-to-sequence'],
#  'then-newly invented sequence-to-sequence': ['transformations'],
#  'invented sequence-to-sequence transformations': [','],
#  'sequence-to-sequence transformations ,': ['made'],
#  'transformations , made': ['obsolete'],
#  ', made obsolete': ['the'],
#  'made obsolete the': ['intermediate'],
#  'obsolete the intermediate': ['steps'],
#  'the intermediate steps': [','],
#  'intermediate steps ,': ['such'],
#  'steps , such': ['as'],
#  ', such as': ['word'],
#  'such as word': ['alignment'],
#  'as word alignment': [','],
#  'word alignment ,': ['previously'],
#  'alignment , previously': ['necessary'],
#  ', previously necessary': ['for'],
#  'previously necessary for': ['statistical'],
#  'necessary for statistical': ['machine'],
#  'for statistical machine': ['translation'],
#  'statistical machine translation': ['.'],
#  'machine translation .': ['The'],
#  'translation . The': ['following'],
#  '. The following': ['is'],
#  'The following is': ['a'],
#  'following is a': ['list'],
#  'is a list': ['of'],
#  'a list of': ['some'],
#  'list of some': ['of'],
#  'of some of': ['the'],
#  'some of the': ['most'],
#  'of the most': ['commonly'],
#  'the most commonly': ['researched'],
#  'most commonly researched': ['tasks'],
#  'commonly researched tasks': ['in'],
#  'researched tasks in': ['natural'],
#  'tasks in natural': ['language'],
#  'processing . Some': ['of'],
#  '. Some of': ['these'],
#  'Some of these': ['tasks'],
#  'of these tasks': ['have'],
#  'these tasks have': ['direct'],
#  'tasks have direct': ['real-world'],
#  'have direct real-world': ['applications'],
#  'direct real-world applications': [','],
#  'real-world applications ,': ['while'],
#  'applications , while': ['others'],
#  ', while others': ['more'],
#  'while others more': ['commonly'],
#  'others more commonly': ['serve'],
#  'more commonly serve': ['as'],
#  'commonly serve as': ['subtasks'],
#  'serve as subtasks': ['that'],
#  'as subtasks that': ['are'],
#  'subtasks that are': ['used'],
#  'that are used': ['to'],
#  'are used to': ['aid'],
#  'used to aid': ['in'],
#  'to aid in': ['solving'],
#  'aid in solving': ['larger'],
#  'in solving larger': ['tasks'],
#  'solving larger tasks': ['.'],
#  'larger tasks .': ['Though'],
#  'tasks . Though': ['natural'],
#  '. Though natural': ['language'],
#  'Though natural language': ['processing'],
#  'language processing tasks': ['are'],
#  'processing tasks are': ['closely'],
#  'tasks are closely': ['intertwined'],
#  'are closely intertwined': [','],
#  'closely intertwined ,': ['they'],
#  'intertwined , they': ['can'],
#  ', they can': ['be'],
#  'they can be': ['subdivided'],
#  'can be subdivided': ['into'],
#  'be subdivided into': ['categories'],
#  'subdivided into categories': ['for'],
#  'into categories for': ['convenience'],
#  'categories for convenience': ['.'],
#  'for convenience .': ['A'],
#  'convenience . A': ['coarse'],
#  '. A coarse': ['division'],
#  'A coarse division': ['is'],
#  'coarse division is': ['given'],
#  'division is given': ['below'],
#  'is given below': ['.'],
#  'given below .': ['Based'],
#  'below . Based': ['on'],
#  '. Based on': ['long-standing'],
#  'Based on long-standing': ['trends'],
#  'on long-standing trends': ['in'],
#  'long-standing trends in': ['the'],
#  'trends in the': ['field'],
#  'in the field': [','],
#  'the field ,': ['it'],
#  'field , it': ['is'],
#  ', it is': ['possible'],
#  'it is possible': ['to'],
#  'is possible to': ['extrapolate'],
#  'possible to extrapolate': ['future'],
#  'to extrapolate future': ['directions'],
#  'extrapolate future directions': ['of'],
#  'future directions of': ['NLP'],
#  'directions of NLP': ['.'],
#  'of NLP .': ['As'],
#  'NLP . As': ['of'],
#  '. As of': ['2020'],
#  'As of 2020': [','],
#  'of 2020 ,': ['three'],
#  '2020 , three': ['trends'],
#  ', three trends': ['among'],
#  'three trends among': ['the'],
#  'trends among the': ['topics'],
#  'among the topics': ['of'],
#  'the topics of': ['the'],
#  'topics of the': ['long-standing'],
#  'of the long-standing': ['series'],
#  'the long-standing series': ['of'],
#  'long-standing series of': ['CoNLL'],
#  'series of CoNLL': ['Shared'],
#  'of CoNLL Shared': ['Tasks'],
#  'CoNLL Shared Tasks': ['can'],
#  'Shared Tasks can': ['be'],
#  'Tasks can be': ['observed'],
#  'can be observed': [':'],
#  'be observed :': ['['],
#  'observed : [': ['49'],
#  ': [ 49': [']'],
#  '[ 49 ]': ['Most'],
#  '49 ] Most': ['higher-level'],
#  '] Most higher-level': ['NLP'],
#  'Most higher-level NLP': ['applications'],
#  'higher-level NLP applications': ['involve'],
#  'NLP applications involve': ['aspects'],
#  'applications involve aspects': ['that'],
#  'involve aspects that': ['emulate'],
#  'aspects that emulate': ['intelligent'],
#  'that emulate intelligent': ['behavior'],
#  'emulate intelligent behavior': ['and'],
#  'intelligent behavior and': ['apparent'],
#  'behavior and apparent': ['comprehension'],
#  'and apparent comprehension': ['of'],
#  'apparent comprehension of': ['natural'],
#  'comprehension of natural': ['language'],
#  'language . More': ['broadly'],
#  '. More broadly': ['speaking'],
#  'More broadly speaking': [','],
#  'broadly speaking ,': ['the'],
#  'speaking , the': ['technical'],
#  ', the technical': ['operationalization'],
#  'the technical operationalization': ['of'],
#  'technical operationalization of': ['increasingly'],
#  'operationalization of increasingly': ['advanced'],
#  'of increasingly advanced': ['aspects'],
#  'increasingly advanced aspects': ['of'],
#  'advanced aspects of': ['cognitive'],
#  'aspects of cognitive': ['behavior'],
#  'of cognitive behavior': ['represents'],
#  'cognitive behavior represents': ['one'],
#  'behavior represents one': ['of'],
#  'represents one of': ['the'],
#  'one of the': ['developmental'],
#  'of the developmental': ['trajectories'],
#  'the developmental trajectories': ['of'],
#  'developmental trajectories of': ['NLP'],
#  'trajectories of NLP': ['('],
#  'of NLP (': ['see'],
#  'NLP ( see': ['trends'],
#  '( see trends': ['among'],
#  'see trends among': ['CoNLL'],
#  'trends among CoNLL': ['shared'],
#  'among CoNLL shared': ['tasks'],
#  'CoNLL shared tasks': ['above'],
#  'shared tasks above': [')'],
#  'tasks above )': ['.'],
#  'above ) .': ['Cognition'],
#  ') . Cognition': ['refers'],
#  '. Cognition refers': ['to'],
#  'Cognition refers to': ['``'],
#  'refers to ``': ['the'],
#  'to `` the': ['mental'],
#  '`` the mental': ['action'],
#  'the mental action': ['or'],
#  'mental action or': ['process'],
#  'action or process': ['of'],
#  'or process of': ['acquiring'],
#  'process of acquiring': ['knowledge'],
#  'of acquiring knowledge': ['and'],
#  'acquiring knowledge and': ['understanding'],
#  'knowledge and understanding': ['through'],
#  'and understanding through': ['thought'],
#  'understanding through thought': [','],
#  'through thought ,': ['experience'],
#  'thought , experience': [','],
#  ', experience ,': ['and'],
#  'experience , and': ['the'],
#  ', and the': ['senses'],
#  'and the senses': ['.'],
#  'the senses .': ['``'],
#  'senses . ``': ['['],
#  '. `` [': ['50'],
#  '`` [ 50': [']'],
#  '[ 50 ]': ['Cognitive'],
#  '50 ] Cognitive': ['science'],
#  '] Cognitive science': ['is'],
#  'Cognitive science is': ['the'],
#  'science is the': ['interdisciplinary'],
#  'is the interdisciplinary': [','],
#  'the interdisciplinary ,': ['scientific'],
#  'interdisciplinary , scientific': ['study'],
#  ', scientific study': ['of'],
#  'scientific study of': ['the'],
#  'study of the': ['mind'],
#  'of the mind': ['and'],
#  'the mind and': ['its'],
#  'mind and its': ['processes'],
#  'and its processes': ['.'],
#  'its processes .': ['['],
#  'processes . [': ['51'],
#  '. [ 51': [']'],
#  '[ 51 ]': ['Cognitive'],
#  '51 ] Cognitive': ['linguistics'],
#  '] Cognitive linguistics': ['is'],
#  'Cognitive linguistics is': ['an'],
#  'linguistics is an': ['interdisciplinary'],
#  'is an interdisciplinary': ['branch'],
#  'an interdisciplinary branch': ['of'],
#  'interdisciplinary branch of': ['linguistics'],
#  'branch of linguistics': [','],
#  'of linguistics ,': ['combining'],
#  'linguistics , combining': ['knowledge'],
#  ', combining knowledge': ['and'],
#  'combining knowledge and': ['research'],
#  'knowledge and research': ['from'],
#  'and research from': ['both'],
#  'research from both': ['psychology'],
#  'from both psychology': ['and'],
#  'both psychology and': ['linguistics'],
#  'psychology and linguistics': ['.'],
#  'and linguistics .': ['['],
#  'linguistics . [': ['52'],
#  '. [ 52': [']'],
#  '[ 52 ]': ['Especially'],
#  '52 ] Especially': ['during'],
#  '] Especially during': ['the'],
#  'Especially during the': ['age'],
#  'during the age': ['of'],
#  'the age of': ['symbolic'],
#  'age of symbolic': ['NLP'],
#  'symbolic NLP ,': ['the'],
#  'NLP , the': ['area'],
#  ', the area': ['of'],
#  'the area of': ['computational'],
#  'area of computational': ['linguistics'],
#  'of computational linguistics': ['maintained'],
#  'computational linguistics maintained': ['strong'],
#  'linguistics maintained strong': ['ties'],
#  'maintained strong ties': ['with'],
#  'strong ties with': ['cognitive'],
#  'ties with cognitive': ['studies'],
#  'with cognitive studies': ['.'],
#  'cognitive studies .': ['As'],
#  'studies . As': ['an'],
#  '. As an': ['example'],
#  'As an example': [','],
#  'an example ,': ['George'],
#  'example , George': ['Lakoff'],
#  ', George Lakoff': ['offers'],
#  'George Lakoff offers': ['a'],
#  'Lakoff offers a': ['methodology'],
#  'offers a methodology': ['to'],
#  'a methodology to': ['build'],
#  'methodology to build': ['natural'],
#  'to build natural': ['language'],
#  'build natural language': ['processing'],
#  'NLP ) algorithms': ['through'],
#  ') algorithms through': ['the'],
#  'algorithms through the': ['perspective'],
#  'through the perspective': ['of'],
#  'the perspective of': ['cognitive'],
#  'perspective of cognitive': ['science'],
#  'of cognitive science': [','],
#  'cognitive science ,': ['along'],
#  'science , along': ['with'],
#  ', along with': ['the'],
#  'along with the': ['findings'],
#  'with the findings': ['of'],
#  'the findings of': ['cognitive'],
#  'findings of cognitive': ['linguistics'],
#  'of cognitive linguistics': [','],
#  'cognitive linguistics ,': ['['],
#  'linguistics , [': ['53'],
#  ', [ 53': [']'],
#  '[ 53 ]': ['with'],
#  '53 ] with': ['two'],
#  '] with two': ['defining'],
#  'with two defining': ['aspects'],
#  'two defining aspects': [':'],
#  'defining aspects :': ['Ties'],
#  'aspects : Ties': ['with'],
#  ': Ties with': ['cognitive'],
#  'Ties with cognitive': ['linguistics'],
#  'with cognitive linguistics': ['are'],
#  'cognitive linguistics are': ['part'],
#  'linguistics are part': ['of'],
#  'are part of': ['the'],
#  'part of the': ['historical'],
#  'of the historical': ['heritage'],
#  'the historical heritage': ['of'],
#  'historical heritage of': ['NLP'],
#  'heritage of NLP': [','],
#  'of NLP ,': ['but'],
#  'NLP , but': ['they'],
#  ', but they': ['have'],
#  'but they have': ['been'],
#  'they have been': ['less'],
#  'have been less': ['frequently'],
#  'been less frequently': ['addressed'],
#  'less frequently addressed': ['since'],
#  'frequently addressed since': ['the'],
#  'addressed since the': ['statistical'],
#  'since the statistical': ['turn'],
#  'the statistical turn': ['during'],
#  'statistical turn during': ['the'],
#  'turn during the': ['1990s'],
#  'during the 1990s': ['.'],
#  'the 1990s .': ['Nevertheless'],
#  '1990s . Nevertheless': [','],
#  '. Nevertheless ,': ['approaches'],
#  'Nevertheless , approaches': ['to'],
#  ', approaches to': ['develop'],
#  'approaches to develop': ['cognitive'],
#  'to develop cognitive': ['models'],
#  'develop cognitive models': ['towards'],
#  'cognitive models towards': ['technically'],
#  'models towards technically': ['operationalizable'],
#  'towards technically operationalizable': ['frameworks'],
#  'technically operationalizable frameworks': ['have'],
#  'operationalizable frameworks have': ['been'],
#  'frameworks have been': ['pursued'],
#  'have been pursued': ['in'],
#  'been pursued in': ['the'],
#  'pursued in the': ['context'],
#  'in the context': ['of'],
#  'the context of': ['various'],
#  'context of various': ['frameworks'],
#  'of various frameworks': [','],
#  'various frameworks ,': ['e.g.'],
#  'frameworks , e.g.': [','],
#  ', e.g. ,': ['of', 'under'],
#  'e.g. , of': ['cognitive'],
#  ', of cognitive': ['grammar'],
#  'of cognitive grammar': [','],
#  'cognitive grammar ,': ['['],
#  'grammar , [': ['56', '57', '58'],
#  ', [ 56': [']'],
#  '[ 56 ]': ['functional'],
#  '56 ] functional': ['grammar'],
#  '] functional grammar': [','],
#  'functional grammar ,': ['['],
#  ', [ 57': [']'],
#  '[ 57 ]': ['construction'],
#  '57 ] construction': ['grammar'],
#  '] construction grammar': [','],
#  'construction grammar ,': ['['],
#  ', [ 58': [']'],
#  '[ 58 ]': ['computational'],
#  '58 ] computational': ['psycholinguistics'],
#  '] computational psycholinguistics': ['and'],
#  'computational psycholinguistics and': ['cognitive'],
#  'psycholinguistics and cognitive': ['neuroscience'],
#  'and cognitive neuroscience': ['('],
#  'cognitive neuroscience (': ['e.g.'],
#  'neuroscience ( e.g.': [','],
#  'e.g. , ACT-R': [')'],
#  ', ACT-R )': [','],
#  'ACT-R ) ,': ['however'],
#  ') , however': [','],
#  'however , with': ['limited'],
#  ', with limited': ['uptake'],
#  'with limited uptake': ['in'],
#  'limited uptake in': ['mainstream'],
#  'uptake in mainstream': ['NLP'],
#  'in mainstream NLP': ['('],
#  'mainstream NLP (': ['as'],
#  'NLP ( as': ['measured'],
#  '( as measured': ['by'],
#  'as measured by': ['presence'],
#  'measured by presence': ['on'],
#  'by presence on': ['major'],
#  'presence on major': ['conferences'],
#  'on major conferences': ['['],
#  'major conferences [': ['59'],
#  'conferences [ 59': [']'],
#  '[ 59 ]': ['of'],
#  '59 ] of': ['the'],
#  '] of the': ['ACL'],
#  'of the ACL': [')'],
#  'the ACL )': ['.'],
#  'ACL ) .': ['More'],
#  ') . More': ['recently'],
#  '. More recently': [','],
#  'More recently ,': ['ideas'],
#  'recently , ideas': ['of'],
#  ', ideas of': ['cognitive', 'cognitive'],
#  'ideas of cognitive': ['NLP', 'NLP'],
#  'of cognitive NLP': ['have', 'are'],
#  'cognitive NLP have': ['been'],
#  'NLP have been': ['revived'],
#  'have been revived': ['as'],
#  'been revived as': ['an'],
#  'revived as an': ['approach'],
#  'as an approach': ['to'],
#  'an approach to': ['achieve'],
#  'approach to achieve': ['explainability'],
#  'to achieve explainability': [','],
#  'achieve explainability ,': ['e.g.'],
#  'explainability , e.g.': [','],
#  'e.g. , under': ['the'],
#  ', under the': ['notion'],
#  'under the notion': ['of'],
#  'the notion of': ['``'],
#  'notion of ``': ['cognitive'],
#  'of `` cognitive': ['AI'],
#  '`` cognitive AI': ["''"],
#  "cognitive AI ''": ['.'],
#  "AI '' .": ['['],
#  "'' . [": ['60'],
#  '. [ 60': [']'],
#  '[ 60 ]': ['Likewise'],
#  '60 ] Likewise': [','],
#  '] Likewise ,': ['ideas'],
#  'Likewise , ideas': ['of'],
#  'cognitive NLP are': ['inherent'],
#  'NLP are inherent': ['to'],
#  'are inherent to': ['neural'],
#  'inherent to neural': ['models'],
#  'to neural models': ['multimodal'],
#  'neural models multimodal': ['NLP'],
#  'models multimodal NLP': ['('],
#  'multimodal NLP (': ['although'],
#  'NLP ( although': ['rarely'],
#  '( although rarely': ['made'],
#  'although rarely made': ['explicit'],
#  'rarely made explicit': [')'],
#  'made explicit )': ['['],
#  'explicit ) [': ['61'],
#  ') [ 61': [']'],
#  '[ 61 ]': ['and'],
#  '61 ] and': ['developments'],
#  '] and developments': ['in'],
#  'and developments in': ['artificial'],
#  'developments in artificial': ['intelligence'],
#  'in artificial intelligence': [','],
#  'artificial intelligence ,': ['specifically'],
#  'intelligence , specifically': ['tools'],
#  ', specifically tools': ['and'],
#  'specifically tools and': ['technologies'],
#  'tools and technologies': ['using'],
#  'and technologies using': ['large'],
#  'technologies using large': ['language'],
#  'using large language': ['model'],
#  'large language model': ['approaches'],
#  'language model approaches': ['['],
#  'model approaches [': ['62'],
#  'approaches [ 62': [']'],
#  '[ 62 ]': ['and'],
#  ...}

# %% [markdown]
# ### Step 5: Testing the N-Grams by generating a sequence

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) algorithms through the perspective of cognitive science , along with the findings of cognitive linguistics , [ 53 ] with two defining aspects : Ties with cognitive linguistics are part of the historical heritage of NLP , but they have been less frequently addressed since the statistical

# %% [markdown]
# ### Building a N-Grams Model with **N-Grams = 4**

# %%
ngrams = {}
words = 4

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])

ngrams
# Out:
# Natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) is
# NLP ) is the
# ) is the processing
# is the processing of
# the processing of natural
# processing of natural language
# of natural language information
# natural language information by
# language information by a
# information by a computer
# by a computer .
# a computer . NLP
# computer . NLP is
# . NLP is a
# NLP is a subfield
# is a subfield of
# a subfield of computer
# subfield of computer science
# of computer science and
# computer science and is
# science and is closely
# and is closely associated
# is closely associated with
# closely associated with artificial
# associated with artificial intelligence
# with artificial intelligence .
# artificial intelligence . NLP
# intelligence . NLP is
# . NLP is also
# NLP is also related
# is also related to
# also related to information
# related to information retrieval
# to information retrieval ,
# information retrieval , knowledge
# retrieval , knowledge representation
# , knowledge representation ,
# knowledge representation , computational
# representation , computational linguistics
# , computational linguistics ,
# computational linguistics , and
# linguistics , and linguistics
# , and linguistics more
# and linguistics more broadly
# linguistics more broadly .
# more broadly . [
# broadly . [ 1
# . [ 1 ]
# [ 1 ] Major
# 1 ] Major processing
# ] Major processing tasks
# Major processing tasks in
# processing tasks in an
# tasks in an NLP
# in an NLP system
# an NLP system include
# NLP system include :
# system include : speech
# include : speech recognition
# : speech recognition ,
# speech recognition , text
# recognition , text classification
# , text classification ,
# text classification , natural
# classification , natural language
# , natural language understanding
# natural language understanding ,
# language understanding , and
# understanding , and natural
# , and natural language
# and natural language generation
# natural language generation .
# language generation . Natural
# generation . Natural language
# . Natural language processing
# Natural language processing has
# language processing has its
# processing has its roots
# has its roots in
# its roots in the
# roots in the 1950s
# in the 1950s .
# the 1950s . [
# 1950s . [ 2
# . [ 2 ]
# [ 2 ] Already
# 2 ] Already in
# ] Already in 1950
# Already in 1950 ,
# in 1950 , Alan
# 1950 , Alan Turing
# , Alan Turing published
# Alan Turing published an
# Turing published an article
# published an article titled
# an article titled ``
# article titled `` Computing
# titled `` Computing Machinery
# `` Computing Machinery and
# Computing Machinery and Intelligence
# Machinery and Intelligence ''
# and Intelligence '' which
# Intelligence '' which proposed
# '' which proposed what
# which proposed what is
# proposed what is now
# what is now called
# is now called the
# now called the Turing
# called the Turing test
# the Turing test as
# Turing test as a
# test as a criterion
# as a criterion of
# a criterion of intelligence
# criterion of intelligence ,
# of intelligence , though
# intelligence , though at
# , though at the
# though at the time
# at the time that
# the time that was
# time that was not
# that was not articulated
# was not articulated as
# not articulated as a
# articulated as a problem
# as a problem separate
# a problem separate from
# problem separate from artificial
# separate from artificial intelligence
# from artificial intelligence .
# artificial intelligence . The
# intelligence . The proposed
# . The proposed test
# The proposed test includes
# proposed test includes a
# test includes a task
# includes a task that
# a task that involves
# task that involves the
# that involves the automated
# involves the automated interpretation
# the automated interpretation and
# automated interpretation and generation
# interpretation and generation of
# and generation of natural
# generation of natural language
# of natural language .
# natural language . The
# language . The premise
# . The premise of
# The premise of symbolic
# premise of symbolic NLP
# of symbolic NLP is
# symbolic NLP is often
# NLP is often illustrated
# is often illustrated using
# often illustrated using John
# illustrated using John Searle
# using John Searle 's
# John Searle 's Chinese
# Searle 's Chinese room
# 's Chinese room thought
# Chinese room thought experiment
# room thought experiment :
# thought experiment : Given
# experiment : Given a
# : Given a collection
# Given a collection of
# a collection of rules
# collection of rules (
# of rules ( e.g.
# rules ( e.g. ,
# ( e.g. , a
# e.g. , a Chinese
# , a Chinese phrasebook
# a Chinese phrasebook ,
# Chinese phrasebook , with
# phrasebook , with questions
# , with questions and
# with questions and matching
# questions and matching answers
# and matching answers )
# matching answers ) ,
# answers ) , the
# ) , the computer
# , the computer emulates
# the computer emulates natural
# computer emulates natural language
# emulates natural language understanding
# natural language understanding (
# language understanding ( or
# understanding ( or other
# ( or other NLP
# or other NLP tasks
# other NLP tasks )
# NLP tasks ) by
# tasks ) by applying
# ) by applying those
# by applying those rules
# applying those rules to
# those rules to the
# rules to the data
# to the data it
# the data it confronts
# data it confronts .
# it confronts . Up
# confronts . Up until
# . Up until the
# Up until the 1980s
# until the 1980s ,
# the 1980s , most
# 1980s , most natural
# , most natural language
# most natural language processing
# natural language processing systems
# language processing systems were
# processing systems were based
# systems were based on
# were based on complex
# based on complex sets
# on complex sets of
# complex sets of hand-written
# sets of hand-written rules
# of hand-written rules .
# hand-written rules . Starting
# rules . Starting in
# . Starting in the
# Starting in the late
# in the late 1980s
# the late 1980s ,
# late 1980s , however
# 1980s , however ,
# , however , there
# however , there was
# , there was a
# there was a revolution
# was a revolution in
# a revolution in natural
# revolution in natural language
# in natural language processing
# natural language processing with
# language processing with the
# processing with the introduction
# with the introduction of
# the introduction of machine
# introduction of machine learning
# of machine learning algorithms
# machine learning algorithms for
# learning algorithms for language
# algorithms for language processing
# for language processing .
# language processing . This
# processing . This shift
# . This shift was
# This shift was influenced
# shift was influenced by
# was influenced by increasing
# influenced by increasing computational
# by increasing computational power
# increasing computational power (
# computational power ( see
# power ( see Moore
# ( see Moore 's
# see Moore 's law
# Moore 's law )
# 's law ) and
# law ) and a
# ) and a decline
# and a decline in
# a decline in the
# decline in the dominance
# in the dominance of
# the dominance of Chomskyan
# dominance of Chomskyan linguistic
# of Chomskyan linguistic theories
# Chomskyan linguistic theories ...
# linguistic theories ... (
# theories ... ( e.g
# ... ( e.g .
# ( e.g . transformational
# e.g . transformational grammar
# . transformational grammar )
# transformational grammar ) ,
# grammar ) , whose
# ) , whose theoretical
# , whose theoretical underpinnings
# whose theoretical underpinnings discouraged
# theoretical underpinnings discouraged the
# underpinnings discouraged the sort
# discouraged the sort of
# the sort of corpus
# sort of corpus linguistics
# of corpus linguistics that
# corpus linguistics that underlies
# linguistics that underlies the
# that underlies the machine-learning
# underlies the machine-learning approach
# the machine-learning approach to
# machine-learning approach to language
# approach to language processing
# to language processing .
# language processing . [
# processing . [ 9
# . [ 9 ]
# [ 9 ] Symbolic
# 9 ] Symbolic approach
# ] Symbolic approach ,
# Symbolic approach , i.e.
# approach , i.e. ,
# , i.e. , the
# i.e. , the hand-coding
# , the hand-coding of
# the hand-coding of a
# hand-coding of a set
# of a set of
# a set of rules
# set of rules for
# of rules for manipulating
# rules for manipulating symbols
# for manipulating symbols ,
# manipulating symbols , coupled
# symbols , coupled with
# , coupled with a
# coupled with a dictionary
# with a dictionary lookup
# a dictionary lookup ,
# dictionary lookup , was
# lookup , was historically
# , was historically the
# was historically the first
# historically the first approach
# the first approach used
# first approach used both
# approach used both by
# used both by AI
# both by AI in
# by AI in general
# AI in general and
# in general and by
# general and by NLP
# and by NLP in
# by NLP in particular
# NLP in particular :
# in particular : [
# particular : [ 19
# : [ 19 ]
# [ 19 ] [
# 19 ] [ 20
# ] [ 20 ]
# [ 20 ] such
# 20 ] such as
# ] such as by
# such as by writing
# as by writing grammars
# by writing grammars or
# writing grammars or devising
# grammars or devising heuristic
# or devising heuristic rules
# devising heuristic rules for
# heuristic rules for stemming
# rules for stemming .
# for stemming . Machine
# stemming . Machine learning
# . Machine learning approaches
# Machine learning approaches ,
# learning approaches , which
# approaches , which include
# , which include both
# which include both statistical
# include both statistical and
# both statistical and neural
# statistical and neural networks
# and neural networks ,
# neural networks , on
# networks , on the
# , on the other
# on the other hand
# the other hand ,
# other hand , have
# hand , have many
# , have many advantages
# have many advantages over
# many advantages over the
# advantages over the symbolic
# over the symbolic approach
# the symbolic approach :
# symbolic approach : Rule-based
# approach : Rule-based systems
# : Rule-based systems are
# Rule-based systems are commonly
# systems are commonly used
# are commonly used :
# commonly used : In
# used : In the
# : In the late
# In the late 1980s
# the late 1980s and
# late 1980s and mid-1990s
# 1980s and mid-1990s ,
# and mid-1990s , the
# mid-1990s , the statistical
# , the statistical approach
# the statistical approach ended
# statistical approach ended a
# approach ended a period
# ended a period of
# a period of AI
# period of AI winter
# of AI winter ,
# AI winter , which
# winter , which was
# , which was caused
# which was caused by
# was caused by the
# caused by the inefficiencies
# by the inefficiencies of
# the inefficiencies of the
# inefficiencies of the rule-based
# of the rule-based approaches
# the rule-based approaches .
# rule-based approaches . [
# approaches . [ 21
# . [ 21 ]
# [ 21 ] [
# 21 ] [ 22
# ] [ 22 ]
# [ 22 ] The
# 22 ] The earliest
# ] The earliest decision
# The earliest decision trees
# earliest decision trees ,
# decision trees , producing
# trees , producing systems
# , producing systems of
# producing systems of hard
# systems of hard if–then
# of hard if–then rules
# hard if–then rules ,
# if–then rules , were
# rules , were still
# , were still very
# were still very similar
# still very similar to
# very similar to the
# similar to the old
# to the old rule-based
# the old rule-based approaches
# old rule-based approaches .
# rule-based approaches . Only
# approaches . Only the
# . Only the introduction
# Only the introduction of
# the introduction of hidden
# introduction of hidden Markov
# of hidden Markov models
# hidden Markov models ,
# Markov models , applied
# models , applied to
# , applied to part-of-speech
# applied to part-of-speech tagging
# to part-of-speech tagging ,
# part-of-speech tagging , announced
# tagging , announced the
# , announced the end
# announced the end of
# the end of the
# end of the old
# of the old rule-based
# the old rule-based approach
# old rule-based approach .
# rule-based approach . A
# approach . A major
# . A major drawback
# A major drawback of
# major drawback of statistical
# drawback of statistical methods
# of statistical methods is
# statistical methods is that
# methods is that they
# is that they require
# that they require elaborate
# they require elaborate feature
# require elaborate feature engineering
# elaborate feature engineering .
# feature engineering . Since
# engineering . Since 2015
# . Since 2015 ,
# Since 2015 , [
# 2015 , [ 23
# , [ 23 ]
# [ 23 ] neural
# 23 ] neural network–based
# ] neural network–based methods
# neural network–based methods have
# network–based methods have increasingly
# methods have increasingly replaced
# have increasingly replaced traditional
# increasingly replaced traditional statistical
# replaced traditional statistical approaches
# traditional statistical approaches ,
# statistical approaches , using
# approaches , using semantic
# , using semantic networks
# using semantic networks [
# semantic networks [ 24
# networks [ 24 ]
# [ 24 ] and
# 24 ] and word
# ] and word embeddings
# and word embeddings to
# word embeddings to capture
# embeddings to capture semantic
# to capture semantic properties
# capture semantic properties of
# semantic properties of words
# properties of words .
# of words . Intermediate
# words . Intermediate tasks
# . Intermediate tasks (
# Intermediate tasks ( e.g.
# tasks ( e.g. ,
# ( e.g. , part-of-speech
# e.g. , part-of-speech tagging
# , part-of-speech tagging and
# part-of-speech tagging and dependency
# tagging and dependency parsing
# and dependency parsing )
# dependency parsing ) are
# parsing ) are not
# ) are not needed
# are not needed anymore
# not needed anymore .
# needed anymore . Neural
# anymore . Neural machine
# . Neural machine translation
# Neural machine translation ,
# machine translation , based
# translation , based on
# , based on then-newly
# based on then-newly invented
# on then-newly invented sequence-to-sequence
# then-newly invented sequence-to-sequence transformations
# invented sequence-to-sequence transformations ,
# sequence-to-sequence transformations , made
# transformations , made obsolete
# , made obsolete the
# made obsolete the intermediate
# obsolete the intermediate steps
# the intermediate steps ,
# intermediate steps , such
# steps , such as
# , such as word
# such as word alignment
# as word alignment ,
# word alignment , previously
# alignment , previously necessary
# , previously necessary for
# previously necessary for statistical
# necessary for statistical machine
# for statistical machine translation
# statistical machine translation .
# machine translation . The
# translation . The following
# . The following is
# The following is a
# following is a list
# is a list of
# a list of some
# list of some of
# of some of the
# some of the most
# of the most commonly
# the most commonly researched
# most commonly researched tasks
# commonly researched tasks in
# researched tasks in natural
# tasks in natural language
# in natural language processing
# natural language processing .
# language processing . Some
# processing . Some of
# . Some of these
# Some of these tasks
# of these tasks have
# these tasks have direct
# tasks have direct real-world
# have direct real-world applications
# direct real-world applications ,
# real-world applications , while
# applications , while others
# , while others more
# while others more commonly
# others more commonly serve
# more commonly serve as
# commonly serve as subtasks
# serve as subtasks that
# as subtasks that are
# subtasks that are used
# that are used to
# are used to aid
# used to aid in
# to aid in solving
# aid in solving larger
# in solving larger tasks
# solving larger tasks .
# larger tasks . Though
# tasks . Though natural
# . Though natural language
# Though natural language processing
# natural language processing tasks
# language processing tasks are
# processing tasks are closely
# tasks are closely intertwined
# are closely intertwined ,
# closely intertwined , they
# intertwined , they can
# , they can be
# they can be subdivided
# can be subdivided into
# be subdivided into categories
# subdivided into categories for
# into categories for convenience
# categories for convenience .
# for convenience . A
# convenience . A coarse
# . A coarse division
# A coarse division is
# coarse division is given
# division is given below
# is given below .
# given below . Based
# below . Based on
# . Based on long-standing
# Based on long-standing trends
# on long-standing trends in
# long-standing trends in the
# trends in the field
# in the field ,
# the field , it
# field , it is
# , it is possible
# it is possible to
# is possible to extrapolate
# possible to extrapolate future
# to extrapolate future directions
# extrapolate future directions of
# future directions of NLP
# directions of NLP .
# of NLP . As
# NLP . As of
# . As of 2020
# As of 2020 ,
# of 2020 , three
# 2020 , three trends
# , three trends among
# three trends among the
# trends among the topics
# among the topics of
# the topics of the
# topics of the long-standing
# of the long-standing series
# the long-standing series of
# long-standing series of CoNLL
# series of CoNLL Shared
# of CoNLL Shared Tasks
# CoNLL Shared Tasks can
# Shared Tasks can be
# Tasks can be observed
# can be observed :
# be observed : [
# observed : [ 49
# : [ 49 ]
# [ 49 ] Most
# 49 ] Most higher-level
# ] Most higher-level NLP
# Most higher-level NLP applications
# higher-level NLP applications involve
# NLP applications involve aspects
# applications involve aspects that
# involve aspects that emulate
# aspects that emulate intelligent
# that emulate intelligent behavior
# emulate intelligent behavior and
# intelligent behavior and apparent
# behavior and apparent comprehension
# and apparent comprehension of
# apparent comprehension of natural
# comprehension of natural language
# of natural language .
# natural language . More
# language . More broadly
# . More broadly speaking
# More broadly speaking ,
# broadly speaking , the
# speaking , the technical
# , the technical operationalization
# the technical operationalization of
# technical operationalization of increasingly
# operationalization of increasingly advanced
# of increasingly advanced aspects
# increasingly advanced aspects of
# advanced aspects of cognitive
# aspects of cognitive behavior
# of cognitive behavior represents
# cognitive behavior represents one
# behavior represents one of
# represents one of the
# one of the developmental
# of the developmental trajectories
# the developmental trajectories of
# developmental trajectories of NLP
# trajectories of NLP (
# of NLP ( see
# NLP ( see trends
# ( see trends among
# see trends among CoNLL
# trends among CoNLL shared
# among CoNLL shared tasks
# CoNLL shared tasks above
# shared tasks above )
# tasks above ) .
# above ) . Cognition
# ) . Cognition refers
# . Cognition refers to
# Cognition refers to ``
# refers to `` the
# to `` the mental
# `` the mental action
# the mental action or
# mental action or process
# action or process of
# or process of acquiring
# process of acquiring knowledge
# of acquiring knowledge and
# acquiring knowledge and understanding
# knowledge and understanding through
# and understanding through thought
# understanding through thought ,
# through thought , experience
# thought , experience ,
# , experience , and
# experience , and the
# , and the senses
# and the senses .
# the senses . ``
# senses . `` [
# . `` [ 50
# `` [ 50 ]
# [ 50 ] Cognitive
# 50 ] Cognitive science
# ] Cognitive science is
# Cognitive science is the
# science is the interdisciplinary
# is the interdisciplinary ,
# the interdisciplinary , scientific
# interdisciplinary , scientific study
# , scientific study of
# scientific study of the
# study of the mind
# of the mind and
# the mind and its
# mind and its processes
# and its processes .
# its processes . [
# processes . [ 51
# . [ 51 ]
# [ 51 ] Cognitive
# 51 ] Cognitive linguistics
# ] Cognitive linguistics is
# Cognitive linguistics is an
# linguistics is an interdisciplinary
# is an interdisciplinary branch
# an interdisciplinary branch of
# interdisciplinary branch of linguistics
# branch of linguistics ,
# of linguistics , combining
# linguistics , combining knowledge
# , combining knowledge and
# combining knowledge and research
# knowledge and research from
# and research from both
# research from both psychology
# from both psychology and
# both psychology and linguistics
# psychology and linguistics .
# and linguistics . [
# linguistics . [ 52
# . [ 52 ]
# [ 52 ] Especially
# 52 ] Especially during
# ] Especially during the
# Especially during the age
# during the age of
# the age of symbolic
# age of symbolic NLP
# of symbolic NLP ,
# symbolic NLP , the
# NLP , the area
# , the area of
# the area of computational
# area of computational linguistics
# of computational linguistics maintained
# computational linguistics maintained strong
# linguistics maintained strong ties
# maintained strong ties with
# strong ties with cognitive
# ties with cognitive studies
# with cognitive studies .
# cognitive studies . As
# studies . As an
# . As an example
# As an example ,
# an example , George
# example , George Lakoff
# , George Lakoff offers
# George Lakoff offers a
# Lakoff offers a methodology
# offers a methodology to
# a methodology to build
# methodology to build natural
# to build natural language
# build natural language processing
# natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) algorithms
# NLP ) algorithms through
# ) algorithms through the
# algorithms through the perspective
# through the perspective of
# the perspective of cognitive
# perspective of cognitive science
# of cognitive science ,
# cognitive science , along
# science , along with
# , along with the
# along with the findings
# with the findings of
# the findings of cognitive
# findings of cognitive linguistics
# of cognitive linguistics ,
# cognitive linguistics , [
# linguistics , [ 53
# , [ 53 ]
# [ 53 ] with
# 53 ] with two
# ] with two defining
# with two defining aspects
# two defining aspects :
# defining aspects : Ties
# aspects : Ties with
# : Ties with cognitive
# Ties with cognitive linguistics
# with cognitive linguistics are
# cognitive linguistics are part
# linguistics are part of
# are part of the
# part of the historical
# of the historical heritage
# the historical heritage of
# historical heritage of NLP
# heritage of NLP ,
# of NLP , but
# NLP , but they
# , but they have
# but they have been
# they have been less
# have been less frequently
# been less frequently addressed
# less frequently addressed since
# frequently addressed since the
# addressed since the statistical
# since the statistical turn
# the statistical turn during
# statistical turn during the
# turn during the 1990s
# during the 1990s .
# the 1990s . Nevertheless
# 1990s . Nevertheless ,
# . Nevertheless , approaches
# Nevertheless , approaches to
# , approaches to develop
# approaches to develop cognitive
# to develop cognitive models
# develop cognitive models towards
# cognitive models towards technically
# models towards technically operationalizable
# towards technically operationalizable frameworks
# technically operationalizable frameworks have
# operationalizable frameworks have been
# frameworks have been pursued
# have been pursued in
# been pursued in the
# pursued in the context
# in the context of
# the context of various
# context of various frameworks
# of various frameworks ,
# various frameworks , e.g.
# frameworks , e.g. ,
# , e.g. , of
# e.g. , of cognitive
# , of cognitive grammar
# of cognitive grammar ,
# cognitive grammar , [
# grammar , [ 56
# , [ 56 ]
# [ 56 ] functional
# 56 ] functional grammar
# ] functional grammar ,
# functional grammar , [
# grammar , [ 57
# , [ 57 ]
# [ 57 ] construction
# 57 ] construction grammar
# ] construction grammar ,
# construction grammar , [
# grammar , [ 58
# , [ 58 ]
# [ 58 ] computational
# 58 ] computational psycholinguistics
# ] computational psycholinguistics and
# computational psycholinguistics and cognitive
# psycholinguistics and cognitive neuroscience
# and cognitive neuroscience (
# cognitive neuroscience ( e.g.
# neuroscience ( e.g. ,
# ( e.g. , ACT-R
# e.g. , ACT-R )
# , ACT-R ) ,
# ACT-R ) , however
# ) , however ,
# , however , with
# however , with limited
# , with limited uptake
# with limited uptake in
# limited uptake in mainstream
# uptake in mainstream NLP
# in mainstream NLP (
# mainstream NLP ( as
# NLP ( as measured
# ( as measured by
# as measured by presence
# measured by presence on
# by presence on major
# presence on major conferences
# on major conferences [
# major conferences [ 59
# conferences [ 59 ]
# [ 59 ] of
# 59 ] of the
# ] of the ACL
# of the ACL )
# the ACL ) .
# ACL ) . More
# ) . More recently
# . More recently ,
# More recently , ideas
# recently , ideas of
# , ideas of cognitive
# ideas of cognitive NLP
# of cognitive NLP have
# cognitive NLP have been
# NLP have been revived
# have been revived as
# been revived as an
# revived as an approach
# as an approach to
# an approach to achieve
# approach to achieve explainability
# to achieve explainability ,
# achieve explainability , e.g.
# explainability , e.g. ,
# , e.g. , under
# e.g. , under the
# , under the notion
# under the notion of
# the notion of ``
# notion of `` cognitive
# of `` cognitive AI
# `` cognitive AI ''
# cognitive AI '' .
# AI '' . [
# '' . [ 60
# . [ 60 ]
# [ 60 ] Likewise
# 60 ] Likewise ,
# ] Likewise , ideas
# Likewise , ideas of
# , ideas of cognitive
# ideas of cognitive NLP
# of cognitive NLP are
# cognitive NLP are inherent
# NLP are inherent to
# are inherent to neural
# inherent to neural models
# to neural models multimodal
# neural models multimodal NLP
# models multimodal NLP (
# multimodal NLP ( although
# NLP ( although rarely
# ( although rarely made
# although rarely made explicit
# rarely made explicit )
# made explicit ) [
# explicit ) [ 61
# ) [ 61 ]
# [ 61 ] and
# 61 ] and developments
# ] and developments in
# and developments in artificial
# developments in artificial intelligence
# in artificial intelligence ,
# artificial intelligence , specifically
# intelligence , specifically tools
# , specifically tools and
# specifically tools and technologies
# tools and technologies using
# and technologies using large
# technologies using large language
# using large language model
# large language model approaches
# language model approaches [
# model approaches [ 62
# approaches [ 62 ]
# [ 62 ] and
# 62 ] and new
# ] and new directions
# and new directions in
# new directions in artificial
# directions in artificial general
# in artificial general intelligence
# artificial general intelligence based
# general intelligence based on
# intelligence based on the
# based on the free
# on the free energy
# the free energy principle
# free energy principle [
# energy principle [ 63
# principle [ 63 ]
# [ 63 ] by
# 63 ] by British
# ] by British neuroscientist
# by British neuroscientist and
# British neuroscientist and theoretician
# neuroscientist and theoretician at
# and theoretician at University
# theoretician at University College
# at University College London
# University College London Karl
# College London Karl J.
# London Karl J. Friston
# {'Natural language processing (': ['NLP'],
#  'language processing ( NLP': [')', ')'],
#  'processing ( NLP )': ['is', 'algorithms'],
#  '( NLP ) is': ['the'],
#  'NLP ) is the': ['processing'],
#  ') is the processing': ['of'],
#  'is the processing of': ['natural'],
#  'the processing of natural': ['language'],
#  'processing of natural language': ['information'],
#  'of natural language information': ['by'],
#  'natural language information by': ['a'],
#  'language information by a': ['computer'],
#  'information by a computer': ['.'],
#  'by a computer .': ['NLP'],
#  'a computer . NLP': ['is'],
#  'computer . NLP is': ['a'],
#  '. NLP is a': ['subfield'],
#  'NLP is a subfield': ['of'],
#  'is a subfield of': ['computer'],
#  'a subfield of computer': ['science'],
#  'subfield of computer science': ['and'],
#  'of computer science and': ['is'],
#  'computer science and is': ['closely'],
#  'science and is closely': ['associated'],
#  'and is closely associated': ['with'],
#  'is closely associated with': ['artificial'],
#  'closely associated with artificial': ['intelligence'],
#  'associated with artificial intelligence': ['.'],
#  'with artificial intelligence .': ['NLP'],
#  'artificial intelligence . NLP': ['is'],
#  'intelligence . NLP is': ['also'],
#  '. NLP is also': ['related'],
#  'NLP is also related': ['to'],
#  'is also related to': ['information'],
#  'also related to information': ['retrieval'],
#  'related to information retrieval': [','],
#  'to information retrieval ,': ['knowledge'],
#  'information retrieval , knowledge': ['representation'],
#  'retrieval , knowledge representation': [','],
#  ', knowledge representation ,': ['computational'],
#  'knowledge representation , computational': ['linguistics'],
#  'representation , computational linguistics': [','],
#  ', computational linguistics ,': ['and'],
#  'computational linguistics , and': ['linguistics'],
#  'linguistics , and linguistics': ['more'],
#  ', and linguistics more': ['broadly'],
#  'and linguistics more broadly': ['.'],
#  'linguistics more broadly .': ['['],
#  'more broadly . [': ['1'],
#  'broadly . [ 1': [']'],
#  '. [ 1 ]': ['Major'],
#  '[ 1 ] Major': ['processing'],
#  '1 ] Major processing': ['tasks'],
#  '] Major processing tasks': ['in'],
#  'Major processing tasks in': ['an'],
#  'processing tasks in an': ['NLP'],
#  'tasks in an NLP': ['system'],
#  'in an NLP system': ['include'],
#  'an NLP system include': [':'],
#  'NLP system include :': ['speech'],
#  'system include : speech': ['recognition'],
#  'include : speech recognition': [','],
#  ': speech recognition ,': ['text'],
#  'speech recognition , text': ['classification'],
#  'recognition , text classification': [','],
#  ', text classification ,': ['natural'],
#  'text classification , natural': ['language'],
#  'classification , natural language': ['understanding'],
#  ', natural language understanding': [','],
#  'natural language understanding ,': ['and'],
#  'language understanding , and': ['natural'],
#  'understanding , and natural': ['language'],
#  ', and natural language': ['generation'],
#  'and natural language generation': ['.'],
#  'natural language generation .': ['Natural'],
#  'language generation . Natural': ['language'],
#  'generation . Natural language': ['processing'],
#  '. Natural language processing': ['has'],
#  'Natural language processing has': ['its'],
#  'language processing has its': ['roots'],
#  'processing has its roots': ['in'],
#  'has its roots in': ['the'],
#  'its roots in the': ['1950s'],
#  'roots in the 1950s': ['.'],
#  'in the 1950s .': ['['],
#  'the 1950s . [': ['2'],
#  '1950s . [ 2': [']'],
#  '. [ 2 ]': ['Already'],
#  '[ 2 ] Already': ['in'],
#  '2 ] Already in': ['1950'],
#  '] Already in 1950': [','],
#  'Already in 1950 ,': ['Alan'],
#  'in 1950 , Alan': ['Turing'],
#  '1950 , Alan Turing': ['published'],
#  ', Alan Turing published': ['an'],
#  'Alan Turing published an': ['article'],
#  'Turing published an article': ['titled'],
#  'published an article titled': ['``'],
#  'an article titled ``': ['Computing'],
#  'article titled `` Computing': ['Machinery'],
#  'titled `` Computing Machinery': ['and'],
#  '`` Computing Machinery and': ['Intelligence'],
#  'Computing Machinery and Intelligence': ["''"],
#  "Machinery and Intelligence ''": ['which'],
#  "and Intelligence '' which": ['proposed'],
#  "Intelligence '' which proposed": ['what'],
#  "'' which proposed what": ['is'],
#  'which proposed what is': ['now'],
#  'proposed what is now': ['called'],
#  'what is now called': ['the'],
#  'is now called the': ['Turing'],
#  'now called the Turing': ['test'],
#  'called the Turing test': ['as'],
#  'the Turing test as': ['a'],
#  'Turing test as a': ['criterion'],
#  'test as a criterion': ['of'],
#  'as a criterion of': ['intelligence'],
#  'a criterion of intelligence': [','],
#  'criterion of intelligence ,': ['though'],
#  'of intelligence , though': ['at'],
#  'intelligence , though at': ['the'],
#  ', though at the': ['time'],
#  'though at the time': ['that'],
#  'at the time that': ['was'],
#  'the time that was': ['not'],
#  'time that was not': ['articulated'],
#  'that was not articulated': ['as'],
#  'was not articulated as': ['a'],
#  'not articulated as a': ['problem'],
#  'articulated as a problem': ['separate'],
#  'as a problem separate': ['from'],
#  'a problem separate from': ['artificial'],
#  'problem separate from artificial': ['intelligence'],
#  'separate from artificial intelligence': ['.'],
#  'from artificial intelligence .': ['The'],
#  'artificial intelligence . The': ['proposed'],
#  'intelligence . The proposed': ['test'],
#  '. The proposed test': ['includes'],
#  'The proposed test includes': ['a'],
#  'proposed test includes a': ['task'],
#  'test includes a task': ['that'],
#  'includes a task that': ['involves'],
#  'a task that involves': ['the'],
#  'task that involves the': ['automated'],
#  'that involves the automated': ['interpretation'],
#  'involves the automated interpretation': ['and'],
#  'the automated interpretation and': ['generation'],
#  'automated interpretation and generation': ['of'],
#  'interpretation and generation of': ['natural'],
#  'and generation of natural': ['language'],
#  'generation of natural language': ['.'],
#  'of natural language .': ['The', 'More'],
#  'natural language . The': ['premise'],
#  'language . The premise': ['of'],
#  '. The premise of': ['symbolic'],
#  'The premise of symbolic': ['NLP'],
#  'premise of symbolic NLP': ['is'],
#  'of symbolic NLP is': ['often'],
#  'symbolic NLP is often': ['illustrated'],
#  'NLP is often illustrated': ['using'],
#  'is often illustrated using': ['John'],
#  'often illustrated using John': ['Searle'],
#  'illustrated using John Searle': ["'s"],
#  "using John Searle 's": ['Chinese'],
#  "John Searle 's Chinese": ['room'],
#  "Searle 's Chinese room": ['thought'],
#  "'s Chinese room thought": ['experiment'],
#  'Chinese room thought experiment': [':'],
#  'room thought experiment :': ['Given'],
#  'thought experiment : Given': ['a'],
#  'experiment : Given a': ['collection'],
#  ': Given a collection': ['of'],
#  'Given a collection of': ['rules'],
#  'a collection of rules': ['('],
#  'collection of rules (': ['e.g.'],
#  'of rules ( e.g.': [','],
#  'rules ( e.g. ,': ['a'],
#  '( e.g. , a': ['Chinese'],
#  'e.g. , a Chinese': ['phrasebook'],
#  ', a Chinese phrasebook': [','],
#  'a Chinese phrasebook ,': ['with'],
#  'Chinese phrasebook , with': ['questions'],
#  'phrasebook , with questions': ['and'],
#  ', with questions and': ['matching'],
#  'with questions and matching': ['answers'],
#  'questions and matching answers': [')'],
#  'and matching answers )': [','],
#  'matching answers ) ,': ['the'],
#  'answers ) , the': ['computer'],
#  ') , the computer': ['emulates'],
#  ', the computer emulates': ['natural'],
#  'the computer emulates natural': ['language'],
#  'computer emulates natural language': ['understanding'],
#  'emulates natural language understanding': ['('],
#  'natural language understanding (': ['or'],
#  'language understanding ( or': ['other'],
#  'understanding ( or other': ['NLP'],
#  '( or other NLP': ['tasks'],
#  'or other NLP tasks': [')'],
#  'other NLP tasks )': ['by'],
#  'NLP tasks ) by': ['applying'],
#  'tasks ) by applying': ['those'],
#  ') by applying those': ['rules'],
#  'by applying those rules': ['to'],
#  'applying those rules to': ['the'],
#  'those rules to the': ['data'],
#  'rules to the data': ['it'],
#  'to the data it': ['confronts'],
#  'the data it confronts': ['.'],
#  'data it confronts .': ['Up'],
#  'it confronts . Up': ['until'],
#  'confronts . Up until': ['the'],
#  '. Up until the': ['1980s'],
#  'Up until the 1980s': [','],
#  'until the 1980s ,': ['most'],
#  'the 1980s , most': ['natural'],
#  '1980s , most natural': ['language'],
#  ', most natural language': ['processing'],
#  'most natural language processing': ['systems'],
#  'natural language processing systems': ['were'],
#  'language processing systems were': ['based'],
#  'processing systems were based': ['on'],
#  'systems were based on': ['complex'],
#  'were based on complex': ['sets'],
#  'based on complex sets': ['of'],
#  'on complex sets of': ['hand-written'],
#  'complex sets of hand-written': ['rules'],
#  'sets of hand-written rules': ['.'],
#  'of hand-written rules .': ['Starting'],
#  'hand-written rules . Starting': ['in'],
#  'rules . Starting in': ['the'],
#  '. Starting in the': ['late'],
#  'Starting in the late': ['1980s'],
#  'in the late 1980s': [','],
#  'the late 1980s ,': ['however'],
#  'late 1980s , however': [','],
#  '1980s , however ,': ['there'],
#  ', however , there': ['was'],
#  'however , there was': ['a'],
#  ', there was a': ['revolution'],
#  'there was a revolution': ['in'],
#  'was a revolution in': ['natural'],
#  'a revolution in natural': ['language'],
#  'revolution in natural language': ['processing'],
#  'in natural language processing': ['with', '.'],
#  'natural language processing with': ['the'],
#  'language processing with the': ['introduction'],
#  'processing with the introduction': ['of'],
#  'with the introduction of': ['machine'],
#  'the introduction of machine': ['learning'],
#  'introduction of machine learning': ['algorithms'],
#  'of machine learning algorithms': ['for'],
#  'machine learning algorithms for': ['language'],
#  'learning algorithms for language': ['processing'],
#  'algorithms for language processing': ['.'],
#  'for language processing .': ['This'],
#  'language processing . This': ['shift'],
#  'processing . This shift': ['was'],
#  '. This shift was': ['influenced'],
#  'This shift was influenced': ['by'],
#  'shift was influenced by': ['increasing'],
#  'was influenced by increasing': ['computational'],
#  'influenced by increasing computational': ['power'],
#  'by increasing computational power': ['('],
#  'increasing computational power (': ['see'],
#  'computational power ( see': ['Moore'],
#  'power ( see Moore': ["'s"],
#  "( see Moore 's": ['law'],
#  "see Moore 's law": [')'],
#  "Moore 's law )": ['and'],
#  "'s law ) and": ['a'],
#  'law ) and a': ['decline'],
#  ') and a decline': ['in'],
#  'and a decline in': ['the'],
#  'a decline in the': ['dominance'],
#  'decline in the dominance': ['of'],
#  'in the dominance of': ['Chomskyan'],
#  'the dominance of Chomskyan': ['linguistic'],
#  'dominance of Chomskyan linguistic': ['theories'],
#  'of Chomskyan linguistic theories': ['...'],
#  'Chomskyan linguistic theories ...': ['('],
#  'linguistic theories ... (': ['e.g'],
#  'theories ... ( e.g': ['.'],
#  '... ( e.g .': ['transformational'],
#  '( e.g . transformational': ['grammar'],
#  'e.g . transformational grammar': [')'],
#  '. transformational grammar )': [','],
#  'transformational grammar ) ,': ['whose'],
#  'grammar ) , whose': ['theoretical'],
#  ') , whose theoretical': ['underpinnings'],
#  ', whose theoretical underpinnings': ['discouraged'],
#  'whose theoretical underpinnings discouraged': ['the'],
#  'theoretical underpinnings discouraged the': ['sort'],
#  'underpinnings discouraged the sort': ['of'],
#  'discouraged the sort of': ['corpus'],
#  'the sort of corpus': ['linguistics'],
#  'sort of corpus linguistics': ['that'],
#  'of corpus linguistics that': ['underlies'],
#  'corpus linguistics that underlies': ['the'],
#  'linguistics that underlies the': ['machine-learning'],
#  'that underlies the machine-learning': ['approach'],
#  'underlies the machine-learning approach': ['to'],
#  'the machine-learning approach to': ['language'],
#  'machine-learning approach to language': ['processing'],
#  'approach to language processing': ['.'],
#  'to language processing .': ['['],
#  'language processing . [': ['9'],
#  'processing . [ 9': [']'],
#  '. [ 9 ]': ['Symbolic'],
#  '[ 9 ] Symbolic': ['approach'],
#  '9 ] Symbolic approach': [','],
#  '] Symbolic approach ,': ['i.e.'],
#  'Symbolic approach , i.e.': [','],
#  'approach , i.e. ,': ['the'],
#  ', i.e. , the': ['hand-coding'],
#  'i.e. , the hand-coding': ['of'],
#  ', the hand-coding of': ['a'],
#  'the hand-coding of a': ['set'],
#  'hand-coding of a set': ['of'],
#  'of a set of': ['rules'],
#  'a set of rules': ['for'],
#  'set of rules for': ['manipulating'],
#  'of rules for manipulating': ['symbols'],
#  'rules for manipulating symbols': [','],
#  'for manipulating symbols ,': ['coupled'],
#  'manipulating symbols , coupled': ['with'],
#  'symbols , coupled with': ['a'],
#  ', coupled with a': ['dictionary'],
#  'coupled with a dictionary': ['lookup'],
#  'with a dictionary lookup': [','],
#  'a dictionary lookup ,': ['was'],
#  'dictionary lookup , was': ['historically'],
#  'lookup , was historically': ['the'],
#  ', was historically the': ['first'],
#  'was historically the first': ['approach'],
#  'historically the first approach': ['used'],
#  'the first approach used': ['both'],
#  'first approach used both': ['by'],
#  'approach used both by': ['AI'],
#  'used both by AI': ['in'],
#  'both by AI in': ['general'],
#  'by AI in general': ['and'],
#  'AI in general and': ['by'],
#  'in general and by': ['NLP'],
#  'general and by NLP': ['in'],
#  'and by NLP in': ['particular'],
#  'by NLP in particular': [':'],
#  'NLP in particular :': ['['],
#  'in particular : [': ['19'],
#  'particular : [ 19': [']'],
#  ': [ 19 ]': ['['],
#  '[ 19 ] [': ['20'],
#  '19 ] [ 20': [']'],
#  '] [ 20 ]': ['such'],
#  '[ 20 ] such': ['as'],
#  '20 ] such as': ['by'],
#  '] such as by': ['writing'],
#  'such as by writing': ['grammars'],
#  'as by writing grammars': ['or'],
#  'by writing grammars or': ['devising'],
#  'writing grammars or devising': ['heuristic'],
#  'grammars or devising heuristic': ['rules'],
#  'or devising heuristic rules': ['for'],
#  'devising heuristic rules for': ['stemming'],
#  'heuristic rules for stemming': ['.'],
#  'rules for stemming .': ['Machine'],
#  'for stemming . Machine': ['learning'],
#  'stemming . Machine learning': ['approaches'],
#  '. Machine learning approaches': [','],
#  'Machine learning approaches ,': ['which'],
#  'learning approaches , which': ['include'],
#  'approaches , which include': ['both'],
#  ', which include both': ['statistical'],
#  'which include both statistical': ['and'],
#  'include both statistical and': ['neural'],
#  'both statistical and neural': ['networks'],
#  'statistical and neural networks': [','],
#  'and neural networks ,': ['on'],
#  'neural networks , on': ['the'],
#  'networks , on the': ['other'],
#  ', on the other': ['hand'],
#  'on the other hand': [','],
#  'the other hand ,': ['have'],
#  'other hand , have': ['many'],
#  'hand , have many': ['advantages'],
#  ', have many advantages': ['over'],
#  'have many advantages over': ['the'],
#  'many advantages over the': ['symbolic'],
#  'advantages over the symbolic': ['approach'],
#  'over the symbolic approach': [':'],
#  'the symbolic approach :': ['Rule-based'],
#  'symbolic approach : Rule-based': ['systems'],
#  'approach : Rule-based systems': ['are'],
#  ': Rule-based systems are': ['commonly'],
#  'Rule-based systems are commonly': ['used'],
#  'systems are commonly used': [':'],
#  'are commonly used :': ['In'],
#  'commonly used : In': ['the'],
#  'used : In the': ['late'],
#  ': In the late': ['1980s'],
#  'In the late 1980s': ['and'],
#  'the late 1980s and': ['mid-1990s'],
#  'late 1980s and mid-1990s': [','],
#  '1980s and mid-1990s ,': ['the'],
#  'and mid-1990s , the': ['statistical'],
#  'mid-1990s , the statistical': ['approach'],
#  ', the statistical approach': ['ended'],
#  'the statistical approach ended': ['a'],
#  'statistical approach ended a': ['period'],
#  'approach ended a period': ['of'],
#  'ended a period of': ['AI'],
#  'a period of AI': ['winter'],
#  'period of AI winter': [','],
#  'of AI winter ,': ['which'],
#  'AI winter , which': ['was'],
#  'winter , which was': ['caused'],
#  ', which was caused': ['by'],
#  'which was caused by': ['the'],
#  'was caused by the': ['inefficiencies'],
#  'caused by the inefficiencies': ['of'],
#  'by the inefficiencies of': ['the'],
#  'the inefficiencies of the': ['rule-based'],
#  'inefficiencies of the rule-based': ['approaches'],
#  'of the rule-based approaches': ['.'],
#  'the rule-based approaches .': ['['],
#  'rule-based approaches . [': ['21'],
#  'approaches . [ 21': [']'],
#  '. [ 21 ]': ['['],
#  '[ 21 ] [': ['22'],
#  '21 ] [ 22': [']'],
#  '] [ 22 ]': ['The'],
#  '[ 22 ] The': ['earliest'],
#  '22 ] The earliest': ['decision'],
#  '] The earliest decision': ['trees'],
#  'The earliest decision trees': [','],
#  'earliest decision trees ,': ['producing'],
#  'decision trees , producing': ['systems'],
#  'trees , producing systems': ['of'],
#  ', producing systems of': ['hard'],
#  'producing systems of hard': ['if–then'],
#  'systems of hard if–then': ['rules'],
#  'of hard if–then rules': [','],
#  'hard if–then rules ,': ['were'],
#  'if–then rules , were': ['still'],
#  'rules , were still': ['very'],
#  ', were still very': ['similar'],
#  'were still very similar': ['to'],
#  'still very similar to': ['the'],
#  'very similar to the': ['old'],
#  'similar to the old': ['rule-based'],
#  'to the old rule-based': ['approaches'],
#  'the old rule-based approaches': ['.'],
#  'old rule-based approaches .': ['Only'],
#  'rule-based approaches . Only': ['the'],
#  'approaches . Only the': ['introduction'],
#  '. Only the introduction': ['of'],
#  'Only the introduction of': ['hidden'],
#  'the introduction of hidden': ['Markov'],
#  'introduction of hidden Markov': ['models'],
#  'of hidden Markov models': [','],
#  'hidden Markov models ,': ['applied'],
#  'Markov models , applied': ['to'],
#  'models , applied to': ['part-of-speech'],
#  ', applied to part-of-speech': ['tagging'],
#  'applied to part-of-speech tagging': [','],
#  'to part-of-speech tagging ,': ['announced'],
#  'part-of-speech tagging , announced': ['the'],
#  'tagging , announced the': ['end'],
#  ', announced the end': ['of'],
#  'announced the end of': ['the'],
#  'the end of the': ['old'],
#  'end of the old': ['rule-based'],
#  'of the old rule-based': ['approach'],
#  'the old rule-based approach': ['.'],
#  'old rule-based approach .': ['A'],
#  'rule-based approach . A': ['major'],
#  'approach . A major': ['drawback'],
#  '. A major drawback': ['of'],
#  'A major drawback of': ['statistical'],
#  'major drawback of statistical': ['methods'],
#  'drawback of statistical methods': ['is'],
#  'of statistical methods is': ['that'],
#  'statistical methods is that': ['they'],
#  'methods is that they': ['require'],
#  'is that they require': ['elaborate'],
#  'that they require elaborate': ['feature'],
#  'they require elaborate feature': ['engineering'],
#  'require elaborate feature engineering': ['.'],
#  'elaborate feature engineering .': ['Since'],
#  'feature engineering . Since': ['2015'],
#  'engineering . Since 2015': [','],
#  '. Since 2015 ,': ['['],
#  'Since 2015 , [': ['23'],
#  '2015 , [ 23': [']'],
#  ', [ 23 ]': ['neural'],
#  '[ 23 ] neural': ['network–based'],
#  '23 ] neural network–based': ['methods'],
#  '] neural network–based methods': ['have'],
#  'neural network–based methods have': ['increasingly'],
#  'network–based methods have increasingly': ['replaced'],
#  'methods have increasingly replaced': ['traditional'],
#  'have increasingly replaced traditional': ['statistical'],
#  'increasingly replaced traditional statistical': ['approaches'],
#  'replaced traditional statistical approaches': [','],
#  'traditional statistical approaches ,': ['using'],
#  'statistical approaches , using': ['semantic'],
#  'approaches , using semantic': ['networks'],
#  ', using semantic networks': ['['],
#  'using semantic networks [': ['24'],
#  'semantic networks [ 24': [']'],
#  'networks [ 24 ]': ['and'],
#  '[ 24 ] and': ['word'],
#  '24 ] and word': ['embeddings'],
#  '] and word embeddings': ['to'],
#  'and word embeddings to': ['capture'],
#  'word embeddings to capture': ['semantic'],
#  'embeddings to capture semantic': ['properties'],
#  'to capture semantic properties': ['of'],
#  'capture semantic properties of': ['words'],
#  'semantic properties of words': ['.'],
#  'properties of words .': ['Intermediate'],
#  'of words . Intermediate': ['tasks'],
#  'words . Intermediate tasks': ['('],
#  '. Intermediate tasks (': ['e.g.'],
#  'Intermediate tasks ( e.g.': [','],
#  'tasks ( e.g. ,': ['part-of-speech'],
#  '( e.g. , part-of-speech': ['tagging'],
#  'e.g. , part-of-speech tagging': ['and'],
#  ', part-of-speech tagging and': ['dependency'],
#  'part-of-speech tagging and dependency': ['parsing'],
#  'tagging and dependency parsing': [')'],
#  'and dependency parsing )': ['are'],
#  'dependency parsing ) are': ['not'],
#  'parsing ) are not': ['needed'],
#  ') are not needed': ['anymore'],
#  'are not needed anymore': ['.'],
#  'not needed anymore .': ['Neural'],
#  'needed anymore . Neural': ['machine'],
#  'anymore . Neural machine': ['translation'],
#  '. Neural machine translation': [','],
#  'Neural machine translation ,': ['based'],
#  'machine translation , based': ['on'],
#  'translation , based on': ['then-newly'],
#  ', based on then-newly': ['invented'],
#  'based on then-newly invented': ['sequence-to-sequence'],
#  'on then-newly invented sequence-to-sequence': ['transformations'],
#  'then-newly invented sequence-to-sequence transformations': [','],
#  'invented sequence-to-sequence transformations ,': ['made'],
#  'sequence-to-sequence transformations , made': ['obsolete'],
#  'transformations , made obsolete': ['the'],
#  ', made obsolete the': ['intermediate'],
#  'made obsolete the intermediate': ['steps'],
#  'obsolete the intermediate steps': [','],
#  'the intermediate steps ,': ['such'],
#  'intermediate steps , such': ['as'],
#  'steps , such as': ['word'],
#  ', such as word': ['alignment'],
#  'such as word alignment': [','],
#  'as word alignment ,': ['previously'],
#  'word alignment , previously': ['necessary'],
#  'alignment , previously necessary': ['for'],
#  ', previously necessary for': ['statistical'],
#  'previously necessary for statistical': ['machine'],
#  'necessary for statistical machine': ['translation'],
#  'for statistical machine translation': ['.'],
#  'statistical machine translation .': ['The'],
#  'machine translation . The': ['following'],
#  'translation . The following': ['is'],
#  '. The following is': ['a'],
# ...
#  'have direct real-world applications': [','],
#  'direct real-world applications ,': ['while'],
#  'real-world applications , while': ['others'],
#  'applications , while others': ['more'],
#  ', while others more': ['commonly'],
#  'while others more commonly': ['serve'],
#  'others more commonly serve': ['as'],
#  'more commonly serve as': ['subtasks'],
#  'commonly serve as subtasks': ['that'],
#  'serve as subtasks that': ['are'],
#  'as subtasks that are': ['used'],
#  'subtasks that are used': ['to'],
#  'that are used to': ['aid'],
#  'are used to aid': ['in'],
#  'used to aid in': ['solving'],
#  'to aid in solving': ['larger'],
#  'aid in solving larger': ['tasks'],
#  'in solving larger tasks': ['.'],
#  'solving larger tasks .': ['Though'],
#  'larger tasks . Though': ['natural'],
#  'tasks . Though natural': ['language'],
#  '. Though natural language': ['processing'],
#  'Though natural language processing': ['tasks'],
#  'natural language processing tasks': ['are'],
#  'language processing tasks are': ['closely'],
#  'processing tasks are closely': ['intertwined'],
#  'tasks are closely intertwined': [','],
#  'are closely intertwined ,': ['they'],
#  'closely intertwined , they': ['can'],
#  'intertwined , they can': ['be'],
#  ', they can be': ['subdivided'],
#  'they can be subdivided': ['into'],
#  'can be subdivided into': ['categories'],
#  'be subdivided into categories': ['for'],
#  'subdivided into categories for': ['convenience'],
#  'into categories for convenience': ['.'],
#  'categories for convenience .': ['A'],
#  'for convenience . A': ['coarse'],
#  'convenience . A coarse': ['division'],
#  '. A coarse division': ['is'],
#  'A coarse division is': ['given'],
#  'coarse division is given': ['below'],
#  'division is given below': ['.'],
#  'is given below .': ['Based'],
#  'given below . Based': ['on'],
#  'below . Based on': ['long-standing'],
#  '. Based on long-standing': ['trends'],
#  'Based on long-standing trends': ['in'],
#  'on long-standing trends in': ['the'],
#  'long-standing trends in the': ['field'],
#  'trends in the field': [','],
#  'in the field ,': ['it'],
#  'the field , it': ['is'],
#  'field , it is': ['possible'],
#  ', it is possible': ['to'],
#  'it is possible to': ['extrapolate'],
#  'is possible to extrapolate': ['future'],
#  'possible to extrapolate future': ['directions'],
#  'to extrapolate future directions': ['of'],
#  'extrapolate future directions of': ['NLP'],
#  'future directions of NLP': ['.'],
#  'directions of NLP .': ['As'],
#  'of NLP . As': ['of'],
#  'NLP . As of': ['2020'],
#  '. As of 2020': [','],
#  'As of 2020 ,': ['three'],
#  'of 2020 , three': ['trends'],
#  '2020 , three trends': ['among'],
#  ', three trends among': ['the'],
#  'three trends among the': ['topics'],
#  'trends among the topics': ['of'],
#  'among the topics of': ['the'],
#  'the topics of the': ['long-standing'],
#  'topics of the long-standing': ['series'],
#  'of the long-standing series': ['of'],
#  'the long-standing series of': ['CoNLL'],
#  'long-standing series of CoNLL': ['Shared'],
#  'series of CoNLL Shared': ['Tasks'],
#  'of CoNLL Shared Tasks': ['can'],
#  'CoNLL Shared Tasks can': ['be'],
#  'Shared Tasks can be': ['observed'],
#  'Tasks can be observed': [':'],
#  'can be observed :': ['['],
#  'be observed : [': ['49'],
#  'observed : [ 49': [']'],
#  ': [ 49 ]': ['Most'],
#  '[ 49 ] Most': ['higher-level'],
#  '49 ] Most higher-level': ['NLP'],
#  '] Most higher-level NLP': ['applications'],
#  'Most higher-level NLP applications': ['involve'],
#  'higher-level NLP applications involve': ['aspects'],
#  'NLP applications involve aspects': ['that'],
#  'applications involve aspects that': ['emulate'],
#  'involve aspects that emulate': ['intelligent'],
#  'aspects that emulate intelligent': ['behavior'],
#  'that emulate intelligent behavior': ['and'],
#  'emulate intelligent behavior and': ['apparent'],
#  'intelligent behavior and apparent': ['comprehension'],
#  'behavior and apparent comprehension': ['of'],
#  'and apparent comprehension of': ['natural'],
#  'apparent comprehension of natural': ['language'],
#  'comprehension of natural language': ['.'],
#  'natural language . More': ['broadly'],
#  'language . More broadly': ['speaking'],
#  '. More broadly speaking': [','],
#  'More broadly speaking ,': ['the'],
#  'broadly speaking , the': ['technical'],
#  'speaking , the technical': ['operationalization'],
#  ', the technical operationalization': ['of'],
#  'the technical operationalization of': ['increasingly'],
#  'technical operationalization of increasingly': ['advanced'],
#  'operationalization of increasingly advanced': ['aspects'],
#  'of increasingly advanced aspects': ['of'],
#  'increasingly advanced aspects of': ['cognitive'],
#  'advanced aspects of cognitive': ['behavior'],
#  'aspects of cognitive behavior': ['represents'],
#  'of cognitive behavior represents': ['one'],
#  'cognitive behavior represents one': ['of'],
#  'behavior represents one of': ['the'],
#  'represents one of the': ['developmental'],
#  'one of the developmental': ['trajectories'],
#  'of the developmental trajectories': ['of'],
#  'the developmental trajectories of': ['NLP'],
#  'developmental trajectories of NLP': ['('],
#  'trajectories of NLP (': ['see'],
#  'of NLP ( see': ['trends'],
#  'NLP ( see trends': ['among'],
#  '( see trends among': ['CoNLL'],
#  'see trends among CoNLL': ['shared'],
#  'trends among CoNLL shared': ['tasks'],
#  'among CoNLL shared tasks': ['above'],
#  'CoNLL shared tasks above': [')'],
#  'shared tasks above )': ['.'],
#  'tasks above ) .': ['Cognition'],
#  'above ) . Cognition': ['refers'],
#  ') . Cognition refers': ['to'],
#  '. Cognition refers to': ['``'],
#  'Cognition refers to ``': ['the'],
#  'refers to `` the': ['mental'],
#  'to `` the mental': ['action'],
#  '`` the mental action': ['or'],
#  'the mental action or': ['process'],
#  'mental action or process': ['of'],
#  'action or process of': ['acquiring'],
#  'or process of acquiring': ['knowledge'],
#  'process of acquiring knowledge': ['and'],
#  'of acquiring knowledge and': ['understanding'],
#  'acquiring knowledge and understanding': ['through'],
#  'knowledge and understanding through': ['thought'],
#  'and understanding through thought': [','],
#  'understanding through thought ,': ['experience'],
#  'through thought , experience': [','],
#  'thought , experience ,': ['and'],
#  ', experience , and': ['the'],
#  'experience , and the': ['senses'],
#  ', and the senses': ['.'],
#  'and the senses .': ['``'],
#  'the senses . ``': ['['],
#  'senses . `` [': ['50'],
#  '. `` [ 50': [']'],
#  '`` [ 50 ]': ['Cognitive'],
#  '[ 50 ] Cognitive': ['science'],
#  '50 ] Cognitive science': ['is'],
#  '] Cognitive science is': ['the'],
#  'Cognitive science is the': ['interdisciplinary'],
#  'science is the interdisciplinary': [','],
#  'is the interdisciplinary ,': ['scientific'],
#  'the interdisciplinary , scientific': ['study'],
#  'interdisciplinary , scientific study': ['of'],
#  ', scientific study of': ['the'],
#  'scientific study of the': ['mind'],
#  'study of the mind': ['and'],
#  'of the mind and': ['its'],
#  'the mind and its': ['processes'],
#  'mind and its processes': ['.'],
#  'and its processes .': ['['],
#  'its processes . [': ['51'],
#  'processes . [ 51': [']'],
#  '. [ 51 ]': ['Cognitive'],
#  '[ 51 ] Cognitive': ['linguistics'],
#  '51 ] Cognitive linguistics': ['is'],
#  '] Cognitive linguistics is': ['an'],
#  'Cognitive linguistics is an': ['interdisciplinary'],
#  'linguistics is an interdisciplinary': ['branch'],
#  'is an interdisciplinary branch': ['of'],
#  'an interdisciplinary branch of': ['linguistics'],
#  'interdisciplinary branch of linguistics': [','],
#  'branch of linguistics ,': ['combining'],
#  'of linguistics , combining': ['knowledge'],
#  'linguistics , combining knowledge': ['and'],
#  ', combining knowledge and': ['research'],
#  'combining knowledge and research': ['from'],
#  'knowledge and research from': ['both'],
#  'and research from both': ['psychology'],
#  'research from both psychology': ['and'],
#  'from both psychology and': ['linguistics'],
#  'both psychology and linguistics': ['.'],
#  'psychology and linguistics .': ['['],
#  'and linguistics . [': ['52'],
#  'linguistics . [ 52': [']'],
#  '. [ 52 ]': ['Especially'],
#  '[ 52 ] Especially': ['during'],
#  '52 ] Especially during': ['the'],
#  '] Especially during the': ['age'],
#  'Especially during the age': ['of'],
#  'during the age of': ['symbolic'],
#  'the age of symbolic': ['NLP'],
#  'age of symbolic NLP': [','],
#  'of symbolic NLP ,': ['the'],
#  'symbolic NLP , the': ['area'],
#  'NLP , the area': ['of'],
#  ', the area of': ['computational'],
#  'the area of computational': ['linguistics'],
#  'area of computational linguistics': ['maintained'],
#  'of computational linguistics maintained': ['strong'],
#  'computational linguistics maintained strong': ['ties'],
#  'linguistics maintained strong ties': ['with'],
#  'maintained strong ties with': ['cognitive'],
#  'strong ties with cognitive': ['studies'],
#  'ties with cognitive studies': ['.'],
#  'with cognitive studies .': ['As'],
#  'cognitive studies . As': ['an'],
#  'studies . As an': ['example'],
#  '. As an example': [','],
#  'As an example ,': ['George'],
#  'an example , George': ['Lakoff'],
#  'example , George Lakoff': ['offers'],
#  ', George Lakoff offers': ['a'],
#  'George Lakoff offers a': ['methodology'],
#  'Lakoff offers a methodology': ['to'],
#  'offers a methodology to': ['build'],
#  'a methodology to build': ['natural'],
#  'methodology to build natural': ['language'],
#  'to build natural language': ['processing'],
#  'build natural language processing': ['('],
#  'natural language processing (': ['NLP'],
#  '( NLP ) algorithms': ['through'],
#  'NLP ) algorithms through': ['the'],
#  ') algorithms through the': ['perspective'],
#  'algorithms through the perspective': ['of'],
#  'through the perspective of': ['cognitive'],
#  'the perspective of cognitive': ['science'],
#  'perspective of cognitive science': [','],
#  'of cognitive science ,': ['along'],
#  'cognitive science , along': ['with'],
#  'science , along with': ['the'],
#  ', along with the': ['findings'],
#  'along with the findings': ['of'],
#  'with the findings of': ['cognitive'],
#  'the findings of cognitive': ['linguistics'],
#  'findings of cognitive linguistics': [','],
#  'of cognitive linguistics ,': ['['],
#  'cognitive linguistics , [': ['53'],
#  'linguistics , [ 53': [']'],
#  ', [ 53 ]': ['with'],
#  '[ 53 ] with': ['two'],
#  '53 ] with two': ['defining'],
#  '] with two defining': ['aspects'],
#  'with two defining aspects': [':'],
#  'two defining aspects :': ['Ties'],
#  'defining aspects : Ties': ['with'],
#  'aspects : Ties with': ['cognitive'],
#  ': Ties with cognitive': ['linguistics'],
#  'Ties with cognitive linguistics': ['are'],
#  'with cognitive linguistics are': ['part'],
#  'cognitive linguistics are part': ['of'],
#  'linguistics are part of': ['the'],
#  'are part of the': ['historical'],
#  'part of the historical': ['heritage'],
#  'of the historical heritage': ['of'],
#  'the historical heritage of': ['NLP'],
#  'historical heritage of NLP': [','],
#  'heritage of NLP ,': ['but'],
#  'of NLP , but': ['they'],
#  'NLP , but they': ['have'],
#  ', but they have': ['been'],
#  'but they have been': ['less'],
#  'they have been less': ['frequently'],
#  'have been less frequently': ['addressed'],
#  'been less frequently addressed': ['since'],
#  'less frequently addressed since': ['the'],
#  'frequently addressed since the': ['statistical'],
#  'addressed since the statistical': ['turn'],
#  'since the statistical turn': ['during'],
#  'the statistical turn during': ['the'],
#  'statistical turn during the': ['1990s'],
#  'turn during the 1990s': ['.'],
#  'during the 1990s .': ['Nevertheless'],
#  'the 1990s . Nevertheless': [','],
#  '1990s . Nevertheless ,': ['approaches'],
#  '. Nevertheless , approaches': ['to'],
#  'Nevertheless , approaches to': ['develop'],
#  ', approaches to develop': ['cognitive'],
#  'approaches to develop cognitive': ['models'],
#  'to develop cognitive models': ['towards'],
#  'develop cognitive models towards': ['technically'],
#  'cognitive models towards technically': ['operationalizable'],
#  'models towards technically operationalizable': ['frameworks'],
#  'towards technically operationalizable frameworks': ['have'],
#  'technically operationalizable frameworks have': ['been'],
#  'operationalizable frameworks have been': ['pursued'],
#  'frameworks have been pursued': ['in'],
#  'have been pursued in': ['the'],
#  'been pursued in the': ['context'],
#  'pursued in the context': ['of'],
#  'in the context of': ['various'],
#  'the context of various': ['frameworks'],
#  'context of various frameworks': [','],
#  'of various frameworks ,': ['e.g.'],
#  'various frameworks , e.g.': [','],
#  'frameworks , e.g. ,': ['of'],
#  ', e.g. , of': ['cognitive'],
#  'e.g. , of cognitive': ['grammar'],
#  ', of cognitive grammar': [','],
#  'of cognitive grammar ,': ['['],
#  'cognitive grammar , [': ['56'],
#  'grammar , [ 56': [']'],
#  ', [ 56 ]': ['functional'],
#  '[ 56 ] functional': ['grammar'],
#  '56 ] functional grammar': [','],
#  '] functional grammar ,': ['['],
#  'functional grammar , [': ['57'],
#  'grammar , [ 57': [']'],
#  ', [ 57 ]': ['construction'],
#  '[ 57 ] construction': ['grammar'],
#  '57 ] construction grammar': [','],
#  '] construction grammar ,': ['['],
#  'construction grammar , [': ['58'],
#  'grammar , [ 58': [']'],
#  ', [ 58 ]': ['computational'],
#  '[ 58 ] computational': ['psycholinguistics'],
#  '58 ] computational psycholinguistics': ['and'],
#  '] computational psycholinguistics and': ['cognitive'],
#  'computational psycholinguistics and cognitive': ['neuroscience'],
#  'psycholinguistics and cognitive neuroscience': ['('],
#  'and cognitive neuroscience (': ['e.g.'],
#  'cognitive neuroscience ( e.g.': [','],
#  'neuroscience ( e.g. ,': ['ACT-R'],
#  '( e.g. , ACT-R': [')'],
#  'e.g. , ACT-R )': [','],
#  ', ACT-R ) ,': ['however'],
#  'ACT-R ) , however': [','],
#  ') , however ,': ['with'],
#  ', however , with': ['limited'],
#  'however , with limited': ['uptake'],
#  ', with limited uptake': ['in'],
#  'with limited uptake in': ['mainstream'],
#  'limited uptake in mainstream': ['NLP'],
#  'uptake in mainstream NLP': ['('],
#  'in mainstream NLP (': ['as'],
#  'mainstream NLP ( as': ['measured'],
#  'NLP ( as measured': ['by'],
#  '( as measured by': ['presence'],
#  'as measured by presence': ['on'],
#  'measured by presence on': ['major'],
#  'by presence on major': ['conferences'],
#  'presence on major conferences': ['['],
#  'on major conferences [': ['59'],
#  'major conferences [ 59': [']'],
#  'conferences [ 59 ]': ['of'],
#  '[ 59 ] of': ['the'],
#  '59 ] of the': ['ACL'],
#  '] of the ACL': [')'],
#  'of the ACL )': ['.'],
#  'the ACL ) .': ['More'],
#  'ACL ) . More': ['recently'],
#  ') . More recently': [','],
#  '. More recently ,': ['ideas'],
#  'More recently , ideas': ['of'],
#  'recently , ideas of': ['cognitive'],
#  ', ideas of cognitive': ['NLP', 'NLP'],
#  'ideas of cognitive NLP': ['have', 'are'],
#  'of cognitive NLP have': ['been'],
#  'cognitive NLP have been': ['revived'],
#  'NLP have been revived': ['as'],
#  'have been revived as': ['an'],
#  'been revived as an': ['approach'],
#  'revived as an approach': ['to'],
#  'as an approach to': ['achieve'],
#  'an approach to achieve': ['explainability'],
#  'approach to achieve explainability': [','],
#  'to achieve explainability ,': ['e.g.'],
#  'achieve explainability , e.g.': [','],
#  'explainability , e.g. ,': ['under'],
#  ', e.g. , under': ['the'],
#  'e.g. , under the': ['notion'],
#  ', under the notion': ['of'],
#  'under the notion of': ['``'],
#  'the notion of ``': ['cognitive'],
#  'notion of `` cognitive': ['AI'],
#  'of `` cognitive AI': ["''"],
#  "`` cognitive AI ''": ['.'],
#  "cognitive AI '' .": ['['],
#  "AI '' . [": ['60'],
#  "'' . [ 60": [']'],
#  '. [ 60 ]': ['Likewise'],
#  '[ 60 ] Likewise': [','],
#  '60 ] Likewise ,': ['ideas'],
#  '] Likewise , ideas': ['of'],
#  'Likewise , ideas of': ['cognitive'],
#  'of cognitive NLP are': ['inherent'],
#  'cognitive NLP are inherent': ['to'],
#  'NLP are inherent to': ['neural'],
#  'are inherent to neural': ['models'],
#  'inherent to neural models': ['multimodal'],
#  'to neural models multimodal': ['NLP'],
#  'neural models multimodal NLP': ['('],
#  'models multimodal NLP (': ['although'],
#  'multimodal NLP ( although': ['rarely'],
#  'NLP ( although rarely': ['made'],
#  ...}

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) is the processing of natural language information by a computer . NLP is a subfield of computer science and is closely associated with artificial intelligence . NLP is also related to information retrieval , knowledge representation , computational linguistics , and linguistics more broadly . [ 1 ]
